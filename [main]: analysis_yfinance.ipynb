# %%
import finvizfinance as fz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from finvizfinance.quote import finvizfinance, Statements, Quote
import yfinance as yf
import math
import sys
import os

# Add the project root to Python path
sys.path.insert(0, '/Users/rssantanu/Desktop/stock_portfolio')


from src.buy_logic import *

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ## Tickers

# %% [markdown]
# #### all combined

# %%
tickers= [
    # current holdings
    "INDIGO.NS", "ADANIPOWER.NS", "ATHERENERG.NS", 
    "BAJAJ-AUTO.NS",
    "BHARTIARTL.NS", "CHOLAFIN.NS", "EICHERMOT.NS", "ZOMATO.NS",
    "HDFCBANK.NS", "ICICIGOLD.NS", "INDIGO.NS", "ITC.NS",
    "JKCEMENT.NS", "JSWENERGY.NS", "JSWSTEEL.NS", "TORNTPHARM.NS",
    "TVSMOTOR.NS", "ZYDUSLIFE.NS", 
    
    # new candidates
    "VOLTAMP.NS", "WAAREEENER.BO", "ADANIGREEN.NS",
    "BDL.NS","BEL.NS","BHARATFORG.NS","LT.NS","SOLARINDS.NS","PREMEXPLN.NS"

    # Land & Real Estate (REITs)
    "EQIX","DLR","NTTYY",          # Keppel DC REIT is SGX; see below

    # Grid & Electrical
    "PWR","ETN","SBGSY","ABB",

    # Thermal / Cooling / HVAC
    "VRT","TT","JCI","DKILY","ATLKY",  # SBGSY, ETN already above

    # Servers / OEM / ODM (US & ADR)
    "SMCI","HPE","DELL","HNHPF","QUCOF","IVTEF","WICOF",

    # Networking & Optics
    "ANET","AVGO","CSCO","MRVL","COHR","LITE","INFN",

    # Compute silicon & power
    "MU","SSNLF","IFNNY","ON","STM","ADI","TXN",

    # Foundry / OSAT / Materials
    "TSM","INTC","ASX","AMKR","SHECY","SUOPY","PLAB",

    # EDA / IP
    "SNPS","CDNS","ANSS",

    # Storage
    "STX","WDC",                   # MU, SSNLF already above

    # Semi Capital Equipment
    "ASML","AMAT","KLAC","LRCX","TOELY",

    # Semiconductor Equipment & Materials
    "NVDA", "AMD", "TSM"

    # Cloud / Data platforms
    "DDOG","SNOW","MDB","ESTC",

    # Security
    "PANW","CRWD","ZS","OKTA",

    # Application / Value Capture
    "GOOGL","MSFT","AMZN","META","ADBE","NFLX","CFLT","PLTR","CRM","NOW","HUBS","QCOM","LNVGY"

    # non-US
    "AJBU.SI",   # Keppel DC REIT (Singapore)
    "9432.T",    # NTT (Tokyo)
    "005930.KS", # Samsung Electronics (Korea)
    "000660.KS", # SK hynix (Korea)
    "2317.TW",   # Foxconn / Hon Hai (Taiwan)
    "2382.TW",   # Quanta (Taiwan)
    "2356.TW",   # Inventec (Taiwan)
    "3231.TW",   # Wistron (Taiwan)
    "SU.PA",     # Schneider Electric (Paris)
    "4063.T",    # Shin-Etsu (Tokyo)
    "3436.T",    # SUMCO (Tokyo)
    "8035.T",    # Tokyo Electron (Tokyo)
    "0992.HK"    # Lenovo (Hong Kong)

    # USA / Canada
    "MP", "UUUU", "NEO.TO", "DEFN.V", "LEM.V", "ARRNF", "AMRRY",  # (OTC ADR for American Rare Earths)
    # Australia
    "LYC.AX", "ILU.AX", "ARU.AX", "NTU.AX", "VML.AX", "REE.AX", "PEK.AX", "ASM.AX", "AR3.AX",
    # UK / Europe
    "PRE.L", "RBW.L",
    # China / Hong Kong (use with market-access caveats)
    "600111.SS", "600392.SS", "0769.HK",
    
    "AVAV","KTOS","LMT","NOC","RTX","GD","LHX","BA","TXT",
    "HII","BWXT","OSK","DRS","LDOS","BAH",
    "TDY","MRCY","TRMB","IRDM","VSAT","CMTL","HEI","TDG","CW","HWM","HON","HXL","GE",
    "NPK","POWW","OLN", 
    "BAESY","BA.L","AM.PA","AIR.PA","LDO.MI","RR.L","SAAB-B.ST","KOG.OL", 
    "HO.PA","HAG.DE","MTX.DE","IDR.MC","UBXN.SW","HEXA-B.ST","OERL.SW","OHB.DE", 
    "RHM.DE","CHG.L", 
    "ESLT","HAL.NS","BEML.NS",
    "012450.KS","047810.KS","064350.KS",
    "7011.T","7012.T","7013.T",
    "ASELS.IS","OTKAR.IS",
    "DRO.AX","EOS.AX","ASB.AX", 
    "6503.T","6701.T",
    "272210.KS",
    "PARAS.NS","DATAPATTNS.NS","ASTRAMICRO.NS","ZENTEC.NS","MTARTECH.NS","DYNAMATECH.NS","SIKA.NS","TANEJAERO.NS",
    "UBXN.SW", 

    "IDEAFORGE.NS",
    "EH",
    "QHL.AX", 
    "BDL.NS","BEL.NS","BHARATFORG.NS","LT.NS","SOLARINDS.NS","PREMEXPLN.NS",

    "CAE","MDA.TO","MAL.TO",

    "DRO.AX","ZENTEC.NS",

    # EO/IR cameras & thermal
    "TDY","DRS","LHX","HAG.DE","HO.PA",
    # Radar / LiDAR
    "OUST","ARBE","HAG.DE","TDY",
    # GNSS / IMU
    "UBXN.SW","HON","KVHI",
    # Comms & control
    "IRDM","VSAT","CMTL","LHX",
    # Edge compute / autonomy chips
    "NVDA","QCOM","AMBA",
    # Airframe / propulsion
    "HXL","HON","SAF.PA","012450.KS",

        # US Big Pharma / Large Biotech
    "LLY","MRK","PFE","ABBV","BMY","AMGN","GILD","REGN","BIIB","VRTX","JNJ","GSK","SNY",
    # Europe / UK / Switzerland / Nordics (incl. some dual-listed in US)
    "NVO","NVS","AZN","ROG.SW","GSK","SNY","BAYN.DE","IPN.PA","UCB.BR","GRFS","HIK.L",
    # India (pharma, biosimilars, APIs, CRDMO)
    "SUNPHARMA.NS","DRREDDY.NS","CIPLA.NS","LUPIN.NS","AUROPHARMA.NS","DIVISLAB.NS","BIOCON.NS",
    "GLENMARK.NS","TORNTPHARM.NS","ZYDUSLIFE.NS","IPCALAB.NS","ALKEM.NS","AJANTPHARM.NS","LAURUSLABS.NS",
    "ABBOTINDIA.NS","PFIZER.NS","SANOFI.NS","NATCOPHARM.NS",
    # Japan
    "TAK","4502.T",  # Takeda ADR + Tokyo
    "4503.T","4523.T","4507.T","4568.T","4519.T","4528.T",  # Astellas, Eisai, Shionogi, Daiichi Sankyo, Chugai (Roche), Ono
    # Korea / Taiwan
    "207940.KS","068270.KQ","091990.KQ",  # Samsung Biologics, Celltrion, Celltrion Healthcare
    "1789.TW","4105.TWO","4142.TWO",      # PharmaEssentia, ScinoPharm, TaiMed (examples)
    # China / Hong Kong (incl. US ADRs)
    "BGNE","6160.HK","HCM","HCM.L","1801.HK","1177.HK","2269.HK","2359.HK","ZLAB",
    # Radiopharma / ADC leaders & partners
    "POINT","MNKKQ","LNTH","ARGX","DARE",  # POINT Biopharma, (Mallinckrodt legacy/OTC if trading), Lantheus, argenx, (DARE small-cap optional)
    # mRNA / RNAi / ASO
    "MRNA","BNTX","CVAC","ALNY","IONS","WVE",
    # Gene Editing (CRISPR / Base / Prime)
    "CRSP","NTLA","BEAM","PRME","EDIT","VERV","CRBU",
    # Cell & Gene Therapy / CAR-T
    "LEGN","KITE","BMY",  # Legend (US), Kite (Gilead unit; watch listing status), BMS (Breyanzi, Abecma)
    # Immuno-oncology / Oncology biotechs
    "IMCR","KRTX","NBIX","INCY","HALO","XENE","EXEL","KURA","MGNX","IMVT","ADAG","RPRX",
    # Neuroscience / Alzheimer’s & more
    "BIIB","LLY","DNLI","ACAD","AXSM","SAGE","ALKS","XENE","PRTA","ANVS",
    # AI-Drug Discovery / Digital Biology (publics)
    "RXRX","EXAI","SDGR","DNLI",  # Recursion, Exscientia, Schrödinger, (Denali = bio not pure AI, kept for neuro)
    # CDMO / Biosimilar Picks & Shovels (incl. a few tools adjacent)
    "LONN.SW","CTLT","WST","TECH","TMO","DHR","SRT3.DE","WUXOF",  # Lonza, Catalent, West, Bio-Techne, Thermo, Danaher, Sartorius pref, WuXi AppTec ADR
    # Additional notable EU/US midcaps
    "MOR","EVR.L","PHIA.AS","XSPRAY.ST","GNFT.PA","BBIO","RVMD","CRNX","ARGX","SWTX",
    # Anti-infectives / Vaccines
    "GSK","SNY","NOVN.SW","SEVNE.ST","NVAX",
    # Dermatology / Ophthalmology specialists (mix global)
    "ALGN","ALCO","AERI","HCM","BHC",
]

# %% [markdown]
# #### current indian equities

# %%
# tickers= [
#     # current holdings
#     "INDIGO.NS", "ADANIPOWER.NS", "ATHERENERG.NS", 
#     "BAJAJ-AUTO.NS",
#     "BHARTIARTL.NS", "CHOLAFIN.NS", "EICHERMOT.NS", "ZOMATO.NS",
#     "HDFCBANK.NS", "ICICIGOLD.NS", "INDIGO.NS", "ITC.NS",
#     "JKCEMENT.NS", "JSWENERGY.NS", "JSWSTEEL.NS", "TORNTPHARM.NS",
#     "TVSMOTOR.NS", "ZYDUSLIFE.NS", 
    
#     # new candidates
#     "VOLTAMP.NS", "WAAREEENER.BO", "ADANIGREEN.NS",
#     "BDL.NS","BEL.NS","BHARATFORG.NS","LT.NS","SOLARINDS.NS","PREMEXPLN.NS"
# ]

# %% [markdown]
# #### AI supply chain

# %%
# tickers = [
#     # Land & Real Estate (REITs)
#     "EQIX","DLR","NTTYY",          # Keppel DC REIT is SGX; see below

#     # Grid & Electrical
#     "PWR","ETN","SBGSY","ABB",

#     # Thermal / Cooling / HVAC
#     "VRT","TT","JCI","DKILY","ATLKY",  # SBGSY, ETN already above

#     # Servers / OEM / ODM (US & ADR)
#     "SMCI","HPE","DELL","HNHPF","QUCOF","IVTEF","WICOF",

#     # Networking & Optics
#     "ANET","AVGO","CSCO","MRVL","COHR","LITE","INFN",

#     # Compute silicon & power
#     "MU","SSNLF","IFNNY","ON","STM","ADI","TXN",

#     # Foundry / OSAT / Materials
#     "TSM","INTC","ASX","AMKR","SHECY","SUOPY","PLAB",

#     # EDA / IP
#     "SNPS","CDNS","ANSS",

#     # Storage
#     "STX","WDC",                   # MU, SSNLF already above

#     # Semi Capital Equipment
#     "ASML","AMAT","KLAC","LRCX","TOELY",

#     # Semiconductor Equipment & Materials
#     "NVDA", "AMD", "TSM"

#     # Cloud / Data platforms
#     "DDOG","SNOW","MDB","ESTC",

#     # Security
#     "PANW","CRWD","ZS","OKTA",

#     # Application / Value Capture
#     "GOOGL","MSFT","AMZN","META","ADBE","NFLX","CFLT","PLTR","CRM","NOW","HUBS","QCOM","LNVGY"

#     # non-US
#     "AJBU.SI",   # Keppel DC REIT (Singapore)
#     "9432.T",    # NTT (Tokyo)
#     "005930.KS", # Samsung Electronics (Korea)
#     "000660.KS", # SK hynix (Korea)
#     "2317.TW",   # Foxconn / Hon Hai (Taiwan)
#     "2382.TW",   # Quanta (Taiwan)
#     "2356.TW",   # Inventec (Taiwan)
#     "3231.TW",   # Wistron (Taiwan)
#     "SU.PA",     # Schneider Electric (Paris)
#     "4063.T",    # Shin-Etsu (Tokyo)
#     "3436.T",    # SUMCO (Tokyo)
#     "8035.T",    # Tokyo Electron (Tokyo)
#     "0992.HK"    # Lenovo (Hong Kong)
# ]

# %% [markdown]
# #### Rare earths

# %%
# tickers = [
#     # USA / Canada
#     "MP", "UUUU", "NEO.TO", "DEFN.V", "LEM.V", "ARRNF", "AMRRY",  # (OTC ADR for American Rare Earths)
#     # Australia
#     "LYC.AX", "ILU.AX", "ARU.AX", "NTU.AX", "VML.AX", "REE.AX", "PEK.AX", "ASM.AX", "AR3.AX",
#     # UK / Europe
#     "PRE.L", "RBW.L",
#     # China / Hong Kong (use with market-access caveats)
#     "600111.SS", "600392.SS", "0769.HK"
# ]

# %% [markdown]
# #### Defence

# %%
# us_platforms = [
#     "AVAV","KTOS","LMT","NOC","RTX","GD","LHX","BA","TXT",
#     "HII","BWXT","OSK","DRS","LDOS","BAH"
# ]

# us_subsystems = [
#     "TDY","MRCY","TRMB","IRDM","VSAT","CMTL","HEI","TDG","CW","HWM","HON","HXL","GE"
# ]

# us_munitions = [
#     "NPK","POWW","OLN"
# ]

# eu_platforms = [
#     "BAESY","BA.L","AM.PA","AIR.PA","LDO.MI","RR.L","SAAB-B.ST","KOG.OL"
# ]

# eu_subsystems = [
#     "HO.PA","HAG.DE","MTX.DE","IDR.MC","UBXN.SW","HEXA-B.ST","OERL.SW","OHB.DE"
# ]

# eu_munitions = [
#     "RHM.DE","CHG.L"
# ]

# asia_platforms = [
#     "ESLT","HAL.NS","BEML.NS",
#     "012450.KS","047810.KS","064350.KS",
#     "7011.T","7012.T","7013.T",
#     "ASELS.IS","OTKAR.IS",
#     "DRO.AX","EOS.AX","ASB.AX"
# ]

# asia_subsystems = [
#     "6503.T","6701.T",
#     "272210.KS",
#     "PARAS.NS","DATAPATTNS.NS","ASTRAMICRO.NS","ZENTEC.NS","MTARTECH.NS","DYNAMATECH.NS","SIKA.NS","TANEJAERO.NS",
#     "UBXN.SW"
# ]

# asia_uav_specialists = [
#     "IDEAFORGE.NS",
#     "EH",
#     "QHL.AX"
# ]

# asia_munitions = [
#     "BDL.NS","BEL.NS","BHARATFORG.NS","LT.NS","SOLARINDS.NS","PREMEXPLN.NS"
# ]

# canada_defense = [
#     "CAE","MDA.TO","MAL.TO"
# ]

# counter_uas = [
#     "DRO.AX","ZENTEC.NS"
# ]

# drone_sensors_equipment = [
#     # EO/IR cameras & thermal
#     "TDY","DRS","LHX","HAG.DE","HO.PA",
#     # Radar / LiDAR
#     "OUST","ARBE","HAG.DE","TDY",
#     # GNSS / IMU
#     "UBXN.SW","HON","KVHI",
#     # Comms & control
#     "IRDM","VSAT","CMTL","LHX",
#     # Edge compute / autonomy chips
#     "NVDA","QCOM","AMBA",
#     # Airframe / propulsion
#     "HXL","HON","SAF.PA","012450.KS"
# ]


# # Combined Universe
# tickers = list(set(
#     us_platforms + us_subsystems + us_munitions +
#     eu_platforms + eu_subsystems + eu_munitions +
#     asia_platforms + asia_subsystems + asia_uav_specialists + asia_munitions +
#     canada_defense + counter_uas + drone_sensors_equipment
# ))

# %% [markdown]
# #### Renewables

# %%
# tickers = [
#     # Solar manufacturing
#     "FSLR", "CSIQ", "JKS", "DQ", "MBTN.SW",
#     "601012.SS", "002459.SZ", "688599.SS", "300118.SZ", "600438.SS",
#     "WAAREEENER.BO", "VIKRAMSOLR.NS", "ADANIENT.NS", "TATAPOWER.NS", "BORORENEW.NS",

#     # Inverters / BOS / trackers
#     "ENPH", "SEDG", "S92.DE", "NXT", "ARRY", "SHLS",
#     "300274.SZ", "300763.SZ", "300827.SZ", "SERVOTECH.NS",

#     # Wind OEMs / components
#     "VWS.CO", "GEV", "ENR.DE", "2208.HK", "2678.HK", "TPICQ", "112610.KQ",

#     # Grid & infrastructure (picks & shovels)
#     "PRY.MI", "NEX.PA", "NKT.CO", "PWR", "ETN", "SU.PA", "ABBN.SW", "HUBB",
#     "POLYCAB.NS", "KEI.NS",

#     # Utility scale / renewable IPPs
#     "NEE", "AES", "CWEN", "BEP", "BEPC", "IBE.MC", "ORSTED.CO", "RWE.DE", "ENGI.PA",
#     "ADANIGREEN.NS", "RNW", "NTPC.NS",

#     # Batteries / storage / cell makers
#     "1211.HK", "300750.SZ", "373220.KS", "006400.KS", "6752.T", "002074.SZ", "3931.HK",
#     "FLNC", "WRT1V.HE", "EXIDEIND.NS", "AMARAJABAT.NS",

#     # Battery materials
#     "ALB", "SQM", "ALTM", "RIO", "FCX", "GLEN.L", "UMI.BR",

#     # Hydrogen / fuel cells
#     "BE", "PLUG", "BLDP", "CWR.L", "NCH2.DE", "NEL.OL", "ITM.L", "ENR.DE",

#     # Heat pumps / HVAC efficiency
#     "CARR", "TT", "JCI", "6367.T", "6503.T", "VOLTAS.NS", "BLUESTARCO.NS",

#     # Geothermal / biofuels niche
#     "ORA", "NESTE.HE"
# ]

# %% [markdown]
# #### Pharma

# %%
# tickers = [
#     # US Big Pharma / Large Biotech
#     "LLY","MRK","PFE","ABBV","BMY","AMGN","GILD","REGN","BIIB","VRTX","JNJ","GSK","SNY",
#     # Europe / UK / Switzerland / Nordics (incl. some dual-listed in US)
#     "NVO","NVS","AZN","ROG.SW","GSK","SNY","BAYN.DE","IPN.PA","UCB.BR","GRFS","HIK.L",
#     # India (pharma, biosimilars, APIs, CRDMO)
#     "SUNPHARMA.NS","DRREDDY.NS","CIPLA.NS","LUPIN.NS","AUROPHARMA.NS","DIVISLAB.NS","BIOCON.NS",
#     "GLENMARK.NS","TORNTPHARM.NS","ZYDUSLIFE.NS","IPCALAB.NS","ALKEM.NS","AJANTPHARM.NS","LAURUSLABS.NS",
#     "ABBOTINDIA.NS","PFIZER.NS","SANOFI.NS","NATCOPHARM.NS",
#     # Japan
#     "TAK","4502.T",  # Takeda ADR + Tokyo
#     "4503.T","4523.T","4507.T","4568.T","4519.T","4528.T",  # Astellas, Eisai, Shionogi, Daiichi Sankyo, Chugai (Roche), Ono
#     # Korea / Taiwan
#     "207940.KS","068270.KQ","091990.KQ",  # Samsung Biologics, Celltrion, Celltrion Healthcare
#     "1789.TW","4105.TWO","4142.TWO",      # PharmaEssentia, ScinoPharm, TaiMed (examples)
#     # China / Hong Kong (incl. US ADRs)
#     "BGNE","6160.HK","HCM","HCM.L","1801.HK","1177.HK","2269.HK","2359.HK","ZLAB",
#     # Radiopharma / ADC leaders & partners
#     "POINT","MNKKQ","LNTH","ARGX","DARE",  # POINT Biopharma, (Mallinckrodt legacy/OTC if trading), Lantheus, argenx, (DARE small-cap optional)
#     # mRNA / RNAi / ASO
#     "MRNA","BNTX","CVAC","ALNY","IONS","WVE",
#     # Gene Editing (CRISPR / Base / Prime)
#     "CRSP","NTLA","BEAM","PRME","EDIT","VERV","CRBU",
#     # Cell & Gene Therapy / CAR-T
#     "LEGN","KITE","BMY",  # Legend (US), Kite (Gilead unit; watch listing status), BMS (Breyanzi, Abecma)
#     # Immuno-oncology / Oncology biotechs
#     "IMCR","KRTX","NBIX","INCY","HALO","XENE","EXEL","KURA","MGNX","IMVT","ADAG","RPRX",
#     # Neuroscience / Alzheimer’s & more
#     "BIIB","LLY","DNLI","ACAD","AXSM","SAGE","ALKS","XENE","PRTA","ANVS",
#     # AI-Drug Discovery / Digital Biology (publics)
#     "RXRX","EXAI","SDGR","DNLI",  # Recursion, Exscientia, Schrödinger, (Denali = bio not pure AI, kept for neuro)
#     # CDMO / Biosimilar Picks & Shovels (incl. a few tools adjacent)
#     "LONN.SW","CTLT","WST","TECH","TMO","DHR","SRT3.DE","WUXOF",  # Lonza, Catalent, West, Bio-Techne, Thermo, Danaher, Sartorius pref, WuXi AppTec ADR
#     # Additional notable EU/US midcaps
#     "MOR","EVR.L","PHIA.AS","XSPRAY.ST","GNFT.PA","BBIO","RVMD","CRNX","ARGX","SWTX",
#     # Anti-infectives / Vaccines
#     "GSK","SNY","NOVN.SW","SEVNE.ST","NVAX",
#     # Dermatology / Ophthalmology specialists (mix global)
#     "ALGN","ALCO","AERI","HCM","BHC",
# ]

# %% [markdown]
# #### MISC

# %%
# tickers = [
#     "EQIX", "DLR",
#     "PWR", "ETN", "ABB",
#     "VRT", "TT", "JCI",
#     "SMCI", "HPE", "DELL",
#     "ANET", "AVGO", "CSCO",
#     "MRVL", "COHR", "LITE", "INFN",
#     "MU", "ON", "STM", "ADI", "TXN",
#     "TSM", "INTC", "ASX", "AMKR", "PLAB",
#     "SNPS", "CDNS", "ANSS",
#     "STX", "WDC",
#     "ASML", "AMAT", "KLAC", "LRCX",
#     "NVDA",
#     "GOOG", "ADBE",
#     "000660.KS", "INDIGO.NS", "NVO", "UNH", "RHM.DE", 
#     "VOLTAMP.NS", "ADANIPOWER.NS", "WAAREEENER.BO", "LLY"
# ]

# tickers = [
#     "WAAREEENER.BO"
# ]

# %% [markdown]
# ## scrape data

# %%
bundles= []

for ticker in tickers:
    print(f'scraping: {ticker}')
    try:
        stock = yf.Ticker(ticker)
    except Exception as e:
        print(f'error scraping {ticker}: {e}')
        continue

    stock_fundamentals = stock.info
    
    income_df_q= stock.quarterly_incomestmt
    cashflow_df_q= stock.quarterly_cashflow
    balance_df_q= stock.quarterly_balance_sheet

    income_df_y= stock.incomestmt
    cashflow_df_y= stock.cashflow
    balance_df_y= stock.balancesheet

    bundle= {
        'fund': stock_fundamentals,
        'inc_q': income_df_q,
        'cf_q': cashflow_df_q,
        'bs_q': balance_df_q,
        'inc_y': income_df_y,
        'cf_y': cashflow_df_y,
        'bs_y': balance_df_y
    }
    bundles.append(bundle)
# Out:
# scraping: INDIGO.NS
# scraping: ADANIPOWER.NS
# scraping: ATHERENERG.NS
# scraping: BAJAJ-AUTO.NS
# scraping: BHARTIARTL.NS
# scraping: CHOLAFIN.NS
# scraping: EICHERMOT.NS
# scraping: ZOMATO.NS
# scraping: HDFCBANK.NS
# scraping: ICICIGOLD.NS
# scraping: INDIGO.NS
# scraping: ITC.NS
# scraping: JKCEMENT.NS
# scraping: JSWENERGY.NS
# scraping: JSWSTEEL.NS
# scraping: TORNTPHARM.NS
# scraping: TVSMOTOR.NS
# scraping: ZYDUSLIFE.NS
# scraping: VOLTAMP.NS
# scraping: WAAREEENER.BO
# scraping: ADANIGREEN.NS
# scraping: BDL.NS
# scraping: BEL.NS
# scraping: BHARATFORG.NS
# scraping: LT.NS
# scraping: SOLARINDS.NS
# scraping: PREMEXPLN.NSEQIX
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: PREMEXPLN.NSEQIX"}}}
# scraping: DLR
# scraping: NTTYY
# scraping: PWR
# scraping: ETN
# scraping: SBGSY
# scraping: ABB
# scraping: VRT
# scraping: TT
# scraping: JCI
# scraping: DKILY
# scraping: ATLKY
# scraping: SMCI
# scraping: HPE
# scraping: DELL
# scraping: HNHPF
# scraping: QUCOF
# scraping: IVTEF
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: IVTEF"}}}
# scraping: WICOF
# scraping: ANET
# scraping: AVGO
# scraping: CSCO
# scraping: MRVL
# scraping: COHR
# scraping: LITE
# scraping: INFN
# scraping: MU
# scraping: SSNLF
# scraping: IFNNY
# scraping: ON
# scraping: STM
# scraping: ADI
# scraping: TXN
# scraping: TSM
# scraping: INTC
# scraping: ASX
# scraping: AMKR
# scraping: SHECY
# scraping: SUOPY
# scraping: PLAB
# scraping: SNPS
# scraping: CDNS
# scraping: ANSS
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ANSS"}}}
# scraping: STX
# scraping: WDC
# scraping: ASML
# scraping: AMAT
# scraping: KLAC
# scraping: LRCX
# scraping: TOELY
# scraping: NVDA
# scraping: AMD
# scraping: TSMDDOG
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TSMDDOG"}}}
# scraping: SNOW
# scraping: MDB
# scraping: ESTC
# scraping: PANW
# scraping: CRWD
# scraping: ZS
# scraping: OKTA
# scraping: GOOGL
# scraping: MSFT
# scraping: AMZN
# scraping: META
# scraping: ADBE
# scraping: NFLX
# scraping: CFLT
# scraping: PLTR
# scraping: CRM
# scraping: NOW
# scraping: HUBS
# scraping: QCOM
# scraping: LNVGYAJBU.SI
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: LNVGYAJBU.SI"}}}
# scraping: 9432.T
# scraping: 005930.KS
# scraping: 000660.KS
# scraping: 2317.TW
# scraping: 2382.TW
# scraping: 2356.TW
# scraping: 3231.TW
# scraping: SU.PA
# scraping: 4063.T
# scraping: 3436.T
# scraping: 8035.T
# scraping: 0992.HKMP
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: 0992.HKMP"}}}
# scraping: UUUU
# scraping: NEO.TO
# scraping: DEFN.V
# scraping: LEM.V
# scraping: ARRNF
# scraping: AMRRY
# scraping: LYC.AX
# scraping: ILU.AX
# scraping: ARU.AX
# scraping: NTU.AX
# scraping: VML.AX
# scraping: REE.AX
# scraping: PEK.AX
# scraping: ASM.AX
# scraping: AR3.AX
# scraping: PRE.L
# scraping: RBW.L
# scraping: 600111.SS
# scraping: 600392.SS
# scraping: 0769.HK
# scraping: AVAV
# scraping: KTOS
# scraping: LMT
# scraping: NOC
# scraping: RTX
# scraping: GD
# scraping: LHX
# scraping: BA
# scraping: TXT
# scraping: HII
# scraping: BWXT
# scraping: OSK
# scraping: DRS
# scraping: LDOS
# scraping: BAH
# scraping: TDY
# scraping: MRCY
# scraping: TRMB
# scraping: IRDM
# scraping: VSAT
# scraping: CMTL
# scraping: HEI
# scraping: TDG
# scraping: CW
# scraping: HWM
# scraping: HON
# scraping: HXL
# scraping: GE
# scraping: NPK
# scraping: POWW
# scraping: OLN
# scraping: BAESY
# scraping: BA.L
# scraping: AM.PA
# scraping: AIR.PA
# scraping: LDO.MI
# scraping: RR.L
# scraping: SAAB-B.ST
# scraping: KOG.OL
# scraping: HO.PA
# scraping: HAG.DE
# scraping: MTX.DE
# scraping: IDR.MC
# scraping: UBXN.SW
# scraping: HEXA-B.ST
# scraping: OERL.SW
# scraping: OHB.DE
# scraping: RHM.DE
# scraping: CHG.L
# scraping: ESLT
# scraping: HAL.NS
# scraping: BEML.NS
# scraping: 012450.KS
# scraping: 047810.KS
# scraping: 064350.KS
# scraping: 7011.T
# scraping: 7012.T
# scraping: 7013.T
# scraping: ASELS.IS
# scraping: OTKAR.IS
# scraping: DRO.AX
# scraping: EOS.AX
# scraping: ASB.AX
# scraping: 6503.T
# scraping: 6701.T
# scraping: 272210.KS
# scraping: PARAS.NS
# scraping: DATAPATTNS.NS
# scraping: ASTRAMICRO.NS
# scraping: ZENTEC.NS
# scraping: MTARTECH.NS
# scraping: DYNAMATECH.NS
# scraping: SIKA.NS
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: SIKA.NS"}}}
# scraping: TANEJAERO.NS
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TANEJAERO.NS"}}}
# scraping: UBXN.SW
# scraping: IDEAFORGE.NS
# scraping: EH
# scraping: QHL.AX
# scraping: BDL.NS
# scraping: BEL.NS
# scraping: BHARATFORG.NS
# scraping: LT.NS
# scraping: SOLARINDS.NS
# scraping: PREMEXPLN.NS
# scraping: CAE
# scraping: MDA.TO
# scraping: MAL.TO
# scraping: DRO.AX
# scraping: ZENTEC.NS
# scraping: TDY
# scraping: DRS
# scraping: LHX
# scraping: HAG.DE
# scraping: HO.PA
# scraping: OUST
# scraping: ARBE
# scraping: HAG.DE
# scraping: TDY
# scraping: UBXN.SW
# scraping: HON
# scraping: KVHI
# scraping: IRDM
# scraping: VSAT
# scraping: CMTL
# scraping: LHX
# scraping: NVDA
# scraping: QCOM
# scraping: AMBA
# scraping: HXL
# scraping: HON
# scraping: SAF.PA
# scraping: 012450.KS
# scraping: LLY
# scraping: MRK
# scraping: PFE
# scraping: ABBV
# scraping: BMY
# scraping: AMGN
# scraping: GILD
# scraping: REGN
# scraping: BIIB
# scraping: VRTX
# scraping: JNJ
# scraping: GSK
# scraping: SNY
# scraping: NVO
# scraping: NVS
# scraping: AZN
# scraping: ROG.SW
# scraping: GSK
# scraping: SNY
# scraping: BAYN.DE
# scraping: IPN.PA
# scraping: UCB.BR
# scraping: GRFS
# scraping: HIK.L
# scraping: SUNPHARMA.NS
# scraping: DRREDDY.NS
# scraping: CIPLA.NS
# scraping: LUPIN.NS
# scraping: AUROPHARMA.NS
# scraping: DIVISLAB.NS
# scraping: BIOCON.NS
# scraping: GLENMARK.NS
# scraping: TORNTPHARM.NS
# scraping: ZYDUSLIFE.NS
# scraping: IPCALAB.NS
# scraping: ALKEM.NS
# scraping: AJANTPHARM.NS
# scraping: LAURUSLABS.NS
# scraping: ABBOTINDIA.NS
# scraping: PFIZER.NS
# scraping: SANOFI.NS
# scraping: NATCOPHARM.NS
# scraping: TAK
# scraping: 4502.T
# scraping: 4503.T
# scraping: 4523.T
# scraping: 4507.T
# scraping: 4568.T
# scraping: 4519.T
# scraping: 4528.T
# scraping: 207940.KS
# scraping: 068270.KQ
# scraping: 091990.KQ
# scraping: 1789.TW
# scraping: 4105.TWO
# scraping: 4142.TWO
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: 4142.TWO"}}}
# scraping: BGNE
# scraping: 6160.HK
# scraping: HCM
# scraping: HCM.L
# scraping: 1801.HK
# scraping: 1177.HK
# scraping: 2269.HK
# scraping: 2359.HK
# scraping: ZLAB
# scraping: POINT
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: POINT"}}}
# scraping: MNKKQ
# scraping: LNTH
# scraping: ARGX
# scraping: DARE
# scraping: MRNA
# scraping: BNTX
# scraping: CVAC
# scraping: ALNY
# scraping: IONS
# scraping: WVE
# scraping: CRSP
# scraping: NTLA
# scraping: BEAM
# scraping: PRME
# scraping: EDIT
# scraping: VERV
# scraping: CRBU
# scraping: LEGN
# scraping: KITE
# scraping: BMY
# scraping: IMCR
# scraping: KRTX
# scraping: NBIX
# scraping: INCY
# scraping: HALO
# scraping: XENE
# scraping: EXEL
# scraping: KURA
# scraping: MGNX
# scraping: IMVT
# scraping: ADAG
# scraping: RPRX
# scraping: BIIB
# scraping: LLY
# scraping: DNLI
# scraping: ACAD
# scraping: AXSM
# scraping: SAGE
# scraping: ALKS
# scraping: XENE
# scraping: PRTA
# scraping: ANVS
# scraping: RXRX
# scraping: EXAI
# scraping: SDGR
# scraping: DNLI
# scraping: LONN.SW
# scraping: CTLT
# scraping: WST
# scraping: TECH
# scraping: TMO
# scraping: DHR
# scraping: SRT3.DE
# scraping: WUXOF
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: WUXOF"}}}
# scraping: MOR
# scraping: EVR.L
# scraping: PHIA.AS
# scraping: XSPRAY.ST
# scraping: GNFT.PA
# scraping: BBIO
# scraping: RVMD
# scraping: CRNX
# scraping: ARGX
# scraping: SWTX
# scraping: GSK
# scraping: SNY
# scraping: NOVN.SW
# scraping: SEVNE.ST
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: SEVNE.ST"}}}
# scraping: NVAX
# scraping: ALGN
# scraping: ALCO
# scraping: AERI
# scraping: HCM
# scraping: BHC

# %% [markdown]
# ## set hyperparameters

# %%
importance_factors = {'growth': 0.3, 'profitability': 0.3, 'valuation': 0.15, 'safety': 0.12, 
'stability': 0.13, 'moat': 0 , 'rd_score': 0, 'invest_score': 0}

# importance_factors = {'growth': 0.3, 'profitability': 0.2, 'valuation': 0.15, 'safety': 0.1, 
# 'stability': 0.05, 'moat': 0.15 , 'rd_score': 0.01, 'invest_score': 0.04}

# %% [markdown]
# ## run the analysis

# %%
rankings, ticker_df = rank_stocks(bundles, importance_factors)
# Out:
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals
# /Users/rssantanu/Desktop/stock_portfolio/src/buy_logic.py:142: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ticker_df.loc[len(ticker_df)] = [name] + metric_vals

# %%
ticker_df.sort_values(by='Score', ascending=False)
# Out:
#                                                Company  Growth Margin  \
# 45                                 Arista Networks Inc          64.24
# 333                        Halozyme Therapeutics, Inc.          77.49
# 76                                  NVIDIA Corporation          69.85
# 236                                 NVIDIA Corporation          69.85
# 256                                   Novo Nordisk A/S          84.26
# 93                          Palantir Technologies Inc.          80.03
# 59   Taiwan Semiconductor Manufacturing Company Lim...          58.98
# 335                                     Exelixis, Inc.          96.59
# 90                                          Adobe Inc.          89.14
# 314                                        BioNTech SE          79.76
# 332                                 Incyte Corporation          42.20
# 331                       Neurocrine Biosciences, Inc.          91.45
# 89                                Meta Platforms, Inc.          81.97
# 101                                      SK hynix Inc.          53.91
# 87                               Microsoft Corporation          68.82
# 326                         Legend Biotech Corporation          12.29
# 252                Vertex Pharmaceuticals Incorporated          52.54
# 232                        Iridium Communications Inc.          71.30
# 149                        Iridium Communications Inc.          71.30
# 4                                Bharti Airtel Limited          65.82
# 310                            Lantheus Holdings, Inc.          63.75
# 5    Cholamandalam Investment and Finance Company L...          99.91
# 368                             BridgeBio Pharma, Inc.          96.19
# 153                       TransDigm Group Incorporated          59.76
# 297                       TTY Biopharm Company Limited          58.01
# 216                                     MDA Space Ltd.          28.23
# 67                        Cadence Design Systems, Inc.          85.55
# 284                               NATCO Pharma Limited          83.11
# 46                                       Broadcom Inc.          77.19
# 86                                       Alphabet Inc.          58.94
# 290                    Daiichi Sankyo Company, Limited          78.54
# 300                                 BeOne Medicines AG          83.51
# 225                                       Ouster, Inc.          42.32
# 169                              Kongsberg Gruppen ASA          60.14
# 19                             Waaree Energies Limited          32.51
# 329                            Immunocore Holdings plc          92.32
# 80                                       MongoDB, Inc.          72.33
# 83                          CrowdStrike Holdings, Inc.          74.16
# 96                                       HubSpot, Inc.          84.55
# 248                                         Amgen Inc.          69.36
# 243                              Eli Lilly and Company          82.64
# 342                              Eli Lilly and Company          82.64
# 375                                        Novartis AG          76.25
# 257                                        Novartis AG          76.25
# 279                              Ajanta Pharma Limited          76.05
# 82                            Palo Alto Networks, Inc.          73.41
# 94                                    Salesforce, Inc.          77.65
# 263                                         Ipsen S.A.          83.32
# 244                                  Merck & Co., Inc.          77.41
# 200                           Zen Technologies Limited          67.02
# 219                           Zen Technologies Limited          67.02
# 238                                    Ambarella, Inc.          59.82
# 246                                        AbbVie Inc.          71.25
# 358                             Bio-Techne Corporation          66.50
# 316                      Alnylam Pharmaceuticals, Inc.          83.64
# 307                                    Zai Lab Limited           8.73
# 341                                        Biogen Inc.          76.30
# 251                                        Biogen Inc.          76.30
# 242                         Hanwha Aerospace Co., Ltd.          22.94
# 183                         Hanwha Aerospace Co., Ltd.          22.94
# 253                                  Johnson & Johnson          68.36
# 95                                    ServiceNow, Inc.          78.52
# 42               Quálitas Controladora, S.A.B. de C.V.          18.06
# 306                              WuXi AppTec Co., Ltd.          47.62
# 351                    Recursion Pharmaceuticals, Inc.           0.00
# 185                              Hyundai Rotem Company          22.84
# 276                         Zydus Lifesciences Limited          71.44
# 17                          Zydus Lifesciences Limited          71.44
# 268                   Dr. Reddy's Laboratories Limited          56.43
# 191                                DroneShield Limited          67.62
# 218                                DroneShield Limited          67.62
# 347                                       Alkermes plc          86.04
# 374                                             Sanofi          72.00
# 85                                          Okta, Inc.          76.91
# 370                    Crinetics Pharmaceuticals, Inc.           0.00
# 261                                             Sanofi          72.00
# 258                                    AstraZeneca PLC          82.26
# 255                                             Sanofi          72.00
# 315                                       CureVac N.V.          94.85
# 92                                     Confluent, Inc.          74.14
# 353                                  Schrödinger, Inc.          58.48
# 71                                   ASML Holding N.V.          52.71
# 81                                        Elastic N.V.          75.29
# 237                              QUALCOMM Incorporated          55.68
# 97                               QUALCOMM Incorporated          55.68
# 320                        Intellia Therapeutics, Inc.           0.00
# 115                       American Rare Earths Limited           0.00
# 116                       American Rare Earths Limited           0.00
# 123                           Peak Rare Earths Limited           0.00
# 84                                       Zscaler, Inc.          76.99
# 336                                Kura Oncology, Inc.        -137.89
# 20                          Adani Green Energy Limited          88.83
# 73                                     KLA Corporation          60.91
# 344                        ACADIA Pharmaceuticals Inc.          60.22
# 371                                          argenx SE          52.15
# 289                               Shionogi & Co., Ltd.          85.61
# 311                                          argenx SE          52.15
# 79                                      Snowflake Inc.          66.79
# 373                                            GSK plc          72.43
# 72                             Applied Materials, Inc.          48.50
# 254                                            GSK plc          72.43
# 260                                            GSK plc          72.43
# 38                          Super Micro Computer, Inc.          11.06
# 345                          Axsome Therapeutics, Inc.          91.48
# 74                            Lam Research Corporation          49.31
# 287                               Astellas Pharma Inc.          81.86
# 33                                  Vertiv Holdings Co          35.72
# 131                                AeroVironment, Inc.          31.00
# 13                                  JSW Energy Limited          62.93
# 214                         Premier Explosives Limited          38.51
# 249                              Gilead Sciences, Inc.          78.53
# 160                            Outdoor Holding Company          97.94
# 207                             EHang Holdings Limited          61.52
# 269                                      Cipla Limited          66.69
# 241                                          Safran SA          49.02
# 267              Sun Pharmaceutical Industries Limited          78.25
# 292                       Ono Pharmaceutical Co., Ltd.          68.74
# 57                                Analog Devices, Inc.          60.15
# 277                          Ipca Laboratories Limited          65.83
# 337                                  MacroGenics, Inc.          -9.73
# 2                                 Ather Energy Limited          17.38
# 91                                       Netflix, Inc.          48.08
# 8                                    HDFC Bank Limited           0.00
# 66                                      Synopsys, Inc.          81.13
# 303                                       INNOVENT BIO          76.62
# 167                           Rolls-Royce Holdings plc          25.26
# 364                                          EVRAZ plc          43.73
# 340                                 Royalty Pharma plc         117.12
# 285              Takeda Pharmaceutical Company Limited          64.98
# 291                    Chugai Pharmaceutical Co., Ltd.          69.48
# 278                         Alkem Laboratories Limited          62.26
# 317                        Ionis Pharmaceuticals, Inc.           5.42
# 250                    Regeneron Pharmaceuticals, Inc.          49.12
# 323                              Editas Medicine, Inc.          -2.57
# 247                       Bristol-Myers Squibb Company          73.92
# 11                                         ITC Limited          54.92
# 328                       Bristol-Myers Squibb Company          73.92
# 312                              Daré Bioscience, Inc.           0.00
# 124                 Australian Strategic Materials Ltd          67.01
# 103                               Quanta Computer Inc.           7.44
# 152                                  HEICO Corporation          39.51
# 111                                  Energy Fuels Inc.           3.25
# 145            Booz Allen Hamilton Holding Corporation          22.40
# 286              Takeda Pharmaceutical Company Limited          64.98
# 270                                      Lupin Limited          68.31
# 271                           Aurobindo Pharma Limited          58.80
# 367                                        Genfit S.A.         100.00
# 121                               Vital Metals Limited          40.92
# 217                     Magellan Aerospace Corporation          12.77
# 189  ASELSAN Elektronik Sanayi ve Ticaret Anonim Si...          31.78
# 119                        Arafura Rare Earths Limited           0.00
# 338                                   Immunovant, Inc.           0.00
# 350                                  Annovis Bio, Inc.           0.00
# 305                       WuXi Biologics (Cayman) Inc.          42.65
# 156                       Honeywell International Inc.          36.94
# 281                               Abbott India Limited          45.28
# 125                     Australian Rare Earths Limited           0.00
# 240                       Honeywell International Inc.          36.94
# 230                       Honeywell International Inc.          36.94
# 118                            Iluka Resources Limited          56.35
# 75                              Tokyo Electron Limited          46.83
# 198                      Data Patterns (India) Limited          60.82
# 293                         Samsung Biologics Co.,Ltd.          52.54
# 36                              Daikin Industries,Ltd.          34.62
# 18                        Voltamp Transformers Limited          27.77
# 199                   Astra Microwave Products Limited          45.56
# 179                                 Chemring Group PLC          68.04
# 348                         Xenon Pharmaceuticals Inc.           0.00
# 58                      Texas Instruments Incorporated          57.48
# 334                         Xenon Pharmaceuticals Inc.           0.00
# 48                            Marvell Technology, Inc.          49.59
# 259                                   Roche Holding AG          74.79
# 105                                Wistron Corporation           6.70
# 114                       Leading Edge Materials Corp.           0.00
# 313                                      Moderna, Inc.         -71.44
# 265                                      Grifols, S.A.          40.09
# 88                                    Amazon.com, Inc.          49.61
# 197       Paras Defence and Space Technologies Limited          53.30
# 142                                Oshkosh Corporation          17.83
# 181                      Hindustan Aeronautics Limited          58.15
# 339                                       Adagene Inc.         100.00
# 34                              Trane Technologies plc          36.26
# 155                              Howmet Aerospace Inc.          32.53
# 15                     Torrent Pharmaceuticals Limited          75.87
# 275                    Torrent Pharmaceuticals Limited          75.87
# 63                        Shin-Etsu Chemical Co., Ltd.          35.70
# 37                               Atlas Copco AB (publ)          42.73
# 122                                      RareX Limited           0.00
# 377                                      Novavax, Inc.          57.18
# 172                                MTU Aero Engines AG          18.37
# 301                           HUTCHMED (China) Limited           8.93
# 381                           HUTCHMED (China) Limited           8.93
# 302                           HUTCHMED (China) Limited           8.93
# 378                             Align Technology, Inc.          69.94
# 190             Otokar Otomotiv ve Savunma Sanayi A.S.          19.93
# 379                                        Alico, Inc.           0.00
# 144                              Leidos Holdings, Inc.          17.56
# 113                               Defense Metals Corp.           0.00
# 1                                  Adani Power Limited          43.30
# 77                        Advanced Micro Devices, Inc.          50.99
# 107                       Shin-Etsu Chemical Co., Ltd.          35.70
# 369                         Revolution Medicines, Inc.           0.00
# 294                                      Celltrion Inc           0.00
# 65                                    Photronics, Inc.          35.81
# 174                                  u-blox Holding AG          48.94
# 132          Kratos Defense & Security Solutions, Inc.          23.61
# 229                                  u-blox Holding AG          48.94
# 159                   National Presto Industries, Inc.          19.23
# 205                                  u-blox Holding AG          48.94
# 47                                 Cisco Systems, Inc.          64.94
# 39                  Hewlett Packard Enterprise Company          29.88
# 194                    Mitsubishi Electric Corporation          31.27
# 168                                     Saab AB (publ)          22.00
# 52                             Micron Technology, Inc.          39.79
# 163                                    BAE Systems plc          12.70
# 283                               Sanofi India Limited          50.80
# 22                          Bharat Electronics Limited          50.14
# 210                         Bharat Electronics Limited          50.14
# 98                                             Unknown           0.00
# 356                                               CTLT           0.00
# 352                                               EXAI           0.00
# 43                                             Unknown           0.00
# 330                                               KRTX           0.00
# 68                                             Unknown           0.00
# 7                                            ZOMATO.NS           0.00
# 9                            ICICI Prudential Gold ETF           0.00
# 322                               Prime Medicine, Inc.           0.00
# 324                                               VERV           0.00
# 327                                               KITE           0.00
# 346                                               SAGE           0.00
# 32                                                 ABB           0.00
# 376                                            Unknown           0.00
# 26                                             Unknown           0.00
# 380                                               AERI           0.00
# 110                                            Unknown           0.00
# 44                                               WICOF           0.00
# 372                                               SWTX           0.00
# 203                                            Unknown           0.00
# 298                                            Unknown           0.00
# 208                                             QHL.AX           0.00
# 309                                              MNKKQ           0.00
# 204                                            Unknown           0.00
# 363                                                MOR           0.00
# 299                                               BGNE           0.00
# 308                                            Unknown           0.00
# 78                                             Unknown           0.00
# 295                                          091990.KQ           0.00
# 362                                            Unknown           0.00
# 51                                                INFN           0.00
# 245                                        Pfizer Inc.          73.82
# 6                                Eicher Motors Limited          43.66
# 109                             Tokyo Electron Limited          46.83
# 16                           TVS Motor Company Limited          38.32
# 157                                 Hexcel Corporation          23.04
# 130                                    CHINA RAREEARTH          -7.00
# 239                                 Hexcel Corporation          23.04
# 127                        Rainbow Rare Earths Limited           0.00
# 349                           Prothena Corporation plc           0.00
# 354                           Denali Therapeutics Inc.           0.00
# 343                           Denali Therapeutics Inc.           0.00
# 273                                     Biocon Limited          60.43
# 187                    Kawasaki Heavy Industries, Ltd.           0.00
# 165                                          Airbus SE          15.36
# 231                               KVH Industries, Inc.          31.39
# 173                               Indra Sistemas, S.A.          25.14
# 136                       General Dynamics Corporation          15.33
# 319                             CRISPR Therapeutics AG           0.00
# 366                            Xspray Pharma AB (publ)           0.00
# 325                          Caribou Biosciences, Inc.           0.00
# 321                             Beam Therapeutics Inc.           0.00
# 55                        ON Semiconductor Corporation          37.88
# 139                                       Textron Inc.          17.80
# 30                               Eaton Corporation plc          38.16
# 53                       Samsung Electronics Co., Ltd.          36.34
# 282                                     Pfizer Limited          64.41
# 126                                        Pensana Plc           0.00
# 266                          Hikma Pharmaceuticals PLC          43.04
# 3                                   Bajaj Auto Limited          32.65
# 24                             Larsen & Toubro Limited          36.32
# 212                            Larsen & Toubro Limited          36.32
# 318                            Wave Life Sciences Ltd.         -80.88
# 29                               Quanta Services, Inc.          15.04
# 12                                 J.K. Cement Limited          63.62
# 69                     Seagate Technology Holdings plc          36.99
# 178                                     Rheinmetall AG          51.32
# 226                                 Arbe Robotics Ltd.          -1.80
# 382                       Bausch Health Companies Inc.          70.70
# 288                                    Eisai Co., Ltd.          78.62
# 134                       Northrop Grumman Corporation          19.42
# 180                                 Elbit Systems Ltd.          24.02
# 360                                Danaher Corporation          59.59
# 162                                    BAE Systems plc          12.70
# 141                             BWX Technologies, Inc.          24.26
# 64                                   Sumco Corporation          17.80
# 106                            Schneider Electric S.E.          42.17
# 154                         Curtiss-Wright Corporation          37.34
# 100                      Samsung Electronics Co., Ltd.          36.34
# 31                             Schneider Electric S.E.          42.17
# 201                          MTAR Technologies Limited          50.77
# 220                 Teledyne Technologies Incorporated          42.73
# 120                          Northern Minerals Limited         100.00
# 228                 Teledyne Technologies Incorporated          42.73
# 146                 Teledyne Technologies Incorporated          42.73
# 272                        Divi's Laboratories Limited          60.34
# 40                              Dell Technologies Inc.          21.26
# 188                                    IHI Corporation          23.18
# 140                Huntington Ingalls Industries, Inc.          12.38
# 170                                        Thales S.A.          26.11
# 224                                        Thales S.A.          26.11
# 27                          Digital Realty Trust, Inc.          54.83
# 175                                  Hexagon AB (publ)          66.36
# 196                           Hanwha Systems Co., Ltd.          13.44
# 56                             STMicroelectronics N.V.          34.60
# 233                                       Viasat, Inc.          32.51
# 150                                       Viasat, Inc.          32.51
# 50                              Lumentum Holdings Inc.          32.95
# 166                                    Leonardo S.p.a.          39.61
# 99                                           NTT, Inc.          27.51
# 25                      Solar Industries India Limited          47.65
# 213                     Solar Industries India Limited          47.65
# 215                                           CAE Inc.          28.09
# 138                                 The Boeing Company          -0.15
# 49                                      Coherent Corp.          35.41
# 357                 West Pharmaceutical Services, Inc.          35.58
# 70                         Western Digital Corporation          38.78
# 264                                             UCB SA          73.38
# 102               Hon Hai Precision Industry Co., Ltd.           6.20
# 104                               Inventec Corporation           5.33
# 280                                Laurus Labs Limited          55.89
# 186                  Mitsubishi Heavy Industries, Ltd.          20.69
# 54                            Infineon Technologies AG          40.99
# 10                         InterGlobe Aviation Limited          33.39
# 0                          InterGlobe Aviation Limited          33.39
# 304                                      SINO BIOPHARM          81.77
# 209                            Bharat Dynamics Limited          49.88
# 21                             Bharat Dynamics Limited          49.88
# 108                                  Sumco Corporation          17.80
# 41                Hon Hai Precision Industry Co., Ltd.           6.20
# 133                        Lockheed Martin Corporation           8.25
# 195                                    NEC Corporation          31.51
# 128  China Northern Rare Earth (Group) High-Tech Co...          11.13
# 148                                       Trimble Inc.          69.58
# 177                                             OHB SE          44.52
# 164                  Dassault Aviation société anonyme          38.62
# 192             Electro Optic Systems Holdings Limited          62.14
# 62                              Amkor Technology, Inc.          13.50
# 135                                    RTX Corporation          20.13
# 206                       ideaForge Technology Limited          35.99
# 296                            ScinoPharm Taiwan, Ltd.          37.68
# 359                      Thermo Fisher Scientific Inc.          41.23
# 112                     Neo Performance Materials Inc.          29.95
# 234                   Comtech Telecommunications Corp.          23.08
# 151                   Comtech Telecommunications Corp.          23.08
# 365                           Koninklijke Philips N.V.          43.84
# 262                           Bayer Aktiengesellschaft          55.02
# 182                                       BEML Limited          49.58
# 355                                     Lonza Group AG          36.47
# 61                    ASE Technology Holding Co., Ltd.          16.68
# 274                   Glenmark Pharmaceuticals Limited          68.35
# 222                        L3Harris Technologies, Inc.          25.74
# 235                        L3Harris Technologies, Inc.          25.74
# 137                        L3Harris Technologies, Inc.          25.74
# 60                                   Intel Corporation          32.55
# 223                                        Hensoldt AG          21.46
# 227                                        Hensoldt AG          21.46
# 171                                        Hensoldt AG          21.46
# 176                         OC Oerlikon Corporation AG          25.57
# 158                                       GE Aerospace          32.46
# 143                                 Leonardo DRS, Inc.          23.40
# 221                                 Leonardo DRS, Inc.          23.40
# 161                                   Olin Corporation           9.25
# 23                                Bharat Forge Limited          55.28
# 193                                     Austal Limited          12.61
# 211                               Bharat Forge Limited          55.28
# 28                                           NTT, Inc.          27.51
# 117                          Lynas Rare Earths Limited          23.33
# 147                              Mercury Systems, Inc.          27.90
# 35                  Johnson Controls International plc          36.36
# 129                 Shenghe Resources Holding Co., Ltd           8.73
# 14                                   JSW Steel Limited          42.04
# 361                       Sartorius Aktiengesellschaft          46.48
# 202                     Dynamatic Technologies Limited          52.43
# 184                   Korea Aerospace Industries, Ltd.          14.14
#
#      Operating Margin     ROE  Forward P/E   PEG  Revenue TTM Growth  \
# 45              44.73   33.64        16.28  2.40               31.33
# 333             62.15    1.79        13.35  0.00               38.10
# 76              60.84  109.42        49.25  1.00               59.70
# 236             60.84  109.42        49.25  1.00               59.70
# 256             43.52   79.17        12.29  1.48               17.24
# 93              26.83   15.20       413.94  3.62               40.49
# 59              50.58   34.66        37.53  1.52               33.70
# 335             37.58   29.00        22.91  0.00               -3.14
# 90              36.29   52.88        16.51  1.00               10.76
# 314             -1.67   -1.84       -26.84  0.00               57.61
# 332             31.57   30.39        15.08  0.13               15.24
# 331             30.10   14.96        22.23  0.00               19.82
# 89              43.02   40.65        26.34  1.98               18.65
# 101             46.56   39.28         8.14  0.71               29.40
# 87              44.90   33.28        35.17  2.26               16.40
# 326             -8.58  -29.65       -48.13  0.00               58.38
# 252             38.93   22.77        22.37  0.00               12.44
# 232             30.88   22.59        18.38  0.43                8.69
# 149             30.88   22.59        18.38  0.43                8.69
# 4               31.08   29.46        30.81  0.00               24.14
# 310             23.27   24.71         8.01  0.00               13.16
# 5               52.51    0.00        21.61  0.00               28.39
# 368           -120.72    0.00       -20.71  0.00             3514.03
# 153             46.80    0.00        30.04  3.75               12.02
# 297             26.88   24.75        15.71  0.00                9.73
# 216             11.68    9.64        28.65  0.00               47.38
# 67              33.82   21.74        49.06  3.08               18.92
# 284             38.63    0.00        19.89  0.00                7.96
# 46              31.77   27.08        61.02  0.55               22.44
# 86              32.43   34.83        31.42  1.67               12.88
# 290             20.38   17.93        25.56  8.20               21.76
# 300              6.68   -4.98      -135.22  0.00               43.48
# 225            -76.53  -46.96       -15.85  0.00               35.61
# 169             12.82   38.20         7.01  2.94               19.36
# 19              19.23   33.70        22.62  0.00               57.97
# 329            -15.18   -5.43       -18.82  0.00               52.18
# 80             -11.04   -3.65       107.27  0.00               26.17
# 83              -6.38   -8.92       126.15  4.12               26.79
# 96              -2.97   -0.65        52.31  0.42               21.51
# 248             32.73   99.14        14.13  0.96                9.23
# 243             45.80   86.29        37.27  0.90               31.37
# 342             45.80   86.29        37.27  0.90               31.37
# 375             31.93   32.62        16.00  1.38               12.35
# 257             31.93   32.62        14.56  1.36               12.35
# 279             25.73    0.00        24.84  0.00               13.18
# 82              13.53   17.45        30.32  1.87               16.72
# 94              22.82   11.20        23.06  1.13               10.64
# 263             26.17   10.89        12.07  0.73                9.15
# 244             37.47   35.42         9.18  0.80                1.56
# 200             34.01   15.87        31.07  0.00               15.73
# 219             34.01   15.87        31.05  0.00               15.73
# 238            -23.02  -15.77      -470.44  0.00               33.43
# 246             37.52  112.85        18.81  0.43                4.68
# 358             36.30    3.68        27.84  0.83                3.48
# 316             -2.09   -2.58      -368.49  0.00               23.66
# 307            -49.91  -28.41       -13.36  0.00               18.70
# 341             34.61    9.13         8.98  0.00                3.89
# 251             34.61    9.13         8.98  0.00                3.89
# 242             13.70   34.31        21.28  0.00              127.19
# 183             13.70   34.31        21.28  0.00              127.19
# 253             30.20   33.62        17.83  1.07                5.27
# 95              12.07   16.95        55.97  1.72               22.58
# 42              13.42   26.82         0.00  0.00               15.65
# 306             42.28   26.36        27.44  0.00               20.15
# 351             -9.17  -86.34        -3.27  0.00               46.89
# 185             18.16   26.76        23.89  0.00               25.18
# 276             27.28    0.00        23.84  0.00                9.38
# 17              27.28    0.00        23.82  0.00                9.38
# 268             18.45   17.36         3.47  3.14               12.44
# 191              1.75    2.22       127.67  0.00               76.48
# 218              1.75    2.22       127.67  0.00               76.48
# 347             22.60   22.35        15.33  0.00                1.48
# 374             28.73    8.83        10.31  0.77               -2.72
# 85               5.63    2.61        30.31  0.47               16.73
# 370           -125.23  -36.94       -11.21  0.00              110.51
# 261             28.73    8.83        10.31  0.77               -2.72
# 258             24.12   19.67        15.00  0.97               12.14
# 255             28.73    8.83        10.31  0.77               -2.72
# 315            -49.59   40.22       -12.18  0.00              -42.00
# 92             -27.91  -29.62        67.20  0.34               24.72
# 353            -96.61  -44.40        -8.28  0.00               15.36
# 71              32.84   53.85        40.28  1.92               20.73
# 81              -2.24   -9.65        47.78  0.00               19.62
# 237             26.65   44.62        14.49  1.94                8.77
# 97              26.65   44.62        14.49  1.94                8.77
# 320             -7.72  -56.95        -2.23  0.00               79.49
# 115            117.27  -20.47         0.00  0.00                 NaN
# 116            117.27  -20.47         0.00  0.00                 NaN
# 123             77.47  -18.11       -22.00  0.00                 NaN
# 84              -3.62   -2.70        90.46  4.19               25.36
# 336             -4.75  -51.11        -3.91  0.00                 NaN
# 20              58.81    8.98        43.55  0.00               34.13
# 73              42.58  100.77        37.00  2.30               19.42
# 344             12.24   33.18        27.73  0.00               14.20
# 371             21.08   24.72        84.66  1.36               88.10
# 289             36.17   12.37        13.49  0.00                9.36
# 311             21.08   24.72        84.66  1.36               88.10
# 79             -29.72  -42.40       291.59 10.21               35.39
# 373             32.61   41.52        10.92  0.38                3.40
# 72              30.58   35.63        24.00  2.25                7.10
# 254             32.61   41.52        10.92  0.38                3.40
# 260             32.61   41.52        10.92  0.38                3.40
# 38               3.97   17.90        11.88  0.00               23.77
# 345            -29.87   -2.81       -61.64  0.00               72.13
# 74              34.35   62.26        37.71  2.39               24.19
# 287             20.57    5.17        21.29  0.00               13.84
# 33              20.49   38.86        56.33  0.91               29.68
# 131            -15.24   -1.70        84.68  0.00              104.74
# 13              42.25    7.46        86.06  0.00               58.91
# 214             18.85    0.00         0.00  0.00               58.48
# 249             39.16   33.40        15.94  0.21                1.81
# 160            -50.69  -20.92         0.00  0.00              -14.71
# 207            -53.08  -30.86        78.70  0.00               61.05
# 269             22.31    0.00        23.68  0.00                4.60
# 241             16.14   34.75        37.33  1.78               22.35
# 267             24.34    0.00        51.85  0.00               10.24
# 292             17.25    0.00        11.09  0.00               10.45
# 57              28.55    5.65        30.89  0.82               19.84
# 277             13.70    0.00        26.70  0.00               11.84
# 337             -1.65  -69.71        -0.66  0.00               81.75
# 2              -28.30    0.00       -46.63  0.00               23.42
# 91              28.22   42.86        45.79  1.29               13.98
# 8               39.47   10.84        10.26  0.00               22.25
# 66               9.50    6.50        29.79  6.18               13.83
# 303             12.99    8.44       793.18  0.00               30.19
# 167             19.03   58.44         0.56  4.91               19.01
# 364             27.06   63.37         0.77  0.00                 NaN
# 340             38.85   17.29         8.41  2.78                5.28
# 285             16.89    1.87        24.96  0.42               -3.27
# 291             46.97   21.52        29.88  4.57                5.40
# 278             19.32    0.00        25.80  0.00                9.87
# 317           -101.91  -39.97       -19.83  0.00               69.12
# 250             29.56   15.19        14.43  1.15                1.32
# 323             -7.12   -1.89        -1.28  0.00              420.67
# 247             33.68   29.32         6.49  0.00                0.80
# 11              29.74    0.00        22.21  0.00               16.94
# 328             33.68   29.32         6.49  0.00                0.80
# 312            180.80    0.00        -1.42  0.00             -194.36
# 124             -3.67  -12.72       -10.10  0.00               19.21
# 103              4.05   35.75        16.22  0.00               46.16
# 152             23.09   16.18        72.51  2.73               19.18
# 111             -6.21  -18.15       363.67  0.00               20.99
# 145              9.79   75.20        11.85  0.00                3.39
# 286             16.89    1.87        29.58  0.42               -3.27
# 270             23.23    0.00        24.10  0.00               11.57
# 271             15.22    0.00        18.35  0.00                6.23
# 367              0.18  -51.74        -5.27  0.00               -5.77
# 121              3.28   -5.85         0.00  0.00                 NaN
# 217              6.62    4.83        20.60  0.00                5.30
# 189             24.90   11.79        21.57  0.00               33.75
# 119              0.00  -13.12       -28.50  0.00                 NaN
# 338              0.00  -77.58        -8.19  0.00                 NaN
# 350              0.00   -3.65        -1.15  0.00                 NaN
# 305             27.37   10.51        35.48  1.80               21.98
# 156             18.50   34.62        18.18  1.83                6.81
# 281             24.51    0.00        34.54  0.00               10.90
# 125              0.00  -15.50         0.00  0.00                 NaN
# 240             18.50   34.62        18.18  1.83                6.81
# 230             18.50   34.62        18.18  1.83                6.81
# 118             21.20    8.00        12.36  0.00               -9.11
# 75              26.33   29.39         0.00  3.90                6.66
# 198             26.77   15.15        45.20  0.00                6.28
# 293             36.87   11.73        45.82  1.73               20.83
# 36               9.99   10.26         0.00  2.01               15.19
# 18              16.35    0.00        21.46  0.00                5.17
# 199             15.83    0.00        41.88  0.00               23.69
# 179             13.61   14.59         0.28  0.00                9.08
# 348            -42.42  -37.65       -11.99  0.00             -100.00
# 58              36.74   29.76        27.30  1.56                9.91
# 334            -42.42  -37.65       -11.99  0.00             -100.00
# 48              14.90   -0.75        35.43  0.00               43.00
# 259             36.14   31.32        12.77  0.72               -0.22
# 105              1.96   24.56        18.05  0.00               92.69
# 114              0.00  -12.45         0.00  0.00                 NaN
# 313             -6.39  -27.50        -3.23  0.00              -39.66
# 265             18.48    4.99         8.18  0.00                6.87
# 88              11.43   24.77        36.24  1.97               12.55
# 197             19.28    0.00        42.53  0.00               15.84
# 142              9.69   15.43        11.38  0.00                0.63
# 181             17.77    0.00        36.57  0.00                9.79
# 339           -322.84  -63.26        -2.78  0.00              -78.35
# 34              20.19   39.08        35.29  2.67                9.38
# 155             25.04   29.98        63.65  0.00               10.74
# 15              26.15    0.00        40.11  0.00               10.89
# 275             26.15    0.00        40.12  0.00               10.89
# 63              25.48   11.57         0.00  0.00                7.28
# 37              20.53   26.41        28.62  2.95               -0.57
# 122              0.00  -84.97         0.00  0.00                 NaN
# 377             44.17    0.00       -52.69  0.00              -14.35
# 172             13.41   24.28        24.57  1.29               20.95
# 301             -1.26   46.90       103.07  0.00               20.96
# 381             -1.26   46.90       103.07  0.00               20.96
# 302             -1.26   46.90        73.00  0.00               20.96
# 378             16.10   11.41        13.49  0.76               -0.97
# 190             13.35  -18.07        13.86  0.00               35.87
# 379             -3.38  -80.39       -94.97  0.00              -34.21
# 144             13.28   30.42        18.27  0.00                4.04
# 113              0.00  -11.85       -14.25  0.00                 NaN
# 1               32.58    0.00       -71.26  0.00                4.02
# 77              -1.27    4.70        49.97  0.52               27.05
# 107             25.48   11.57        14.12  0.00                7.28
# 369              0.00  -46.61       -14.54  0.00             -100.00
# 294              0.00    0.00         0.00  0.84               13.96
# 65              22.89   10.29        10.88  0.00                2.60
# 174             -9.61  -24.00      -182.43  0.00              -14.05
# 132              1.05    0.88       149.66  0.00               15.55
# 229             -9.61  -24.00      -182.43  0.00              -14.05
# 159              7.30   11.68       121.30  0.00               30.01
# 205             -9.61  -24.00      -182.43  0.00              -14.05
# 47              21.28   22.06        18.69  1.63                6.25
# 39               5.50    5.36        11.62  4.75               13.77
# 194              8.53    0.00        26.14  2.31                7.24
# 168              8.59   13.55        51.32  1.61               26.59
# 52              32.64   17.20        17.41  0.18               -3.22
# 163              9.23   18.37         0.24  4.11               10.46
# 283             27.07    0.00        23.49  0.00              -12.25
# 22              25.17    0.00        53.61  0.00                7.82
# 210             25.17    0.00        54.45  0.00                7.82
# 98               0.00    0.00         0.00  0.00                 NaN
# 356              0.00    0.00         0.00  0.00                 NaN
# 352              0.00    0.00         0.00  0.00                 NaN
# 43               0.00    0.00         0.00  0.00                 NaN
# 330              0.00    0.00         0.00  0.00                 NaN
# 68               0.00    0.00         0.00  0.00                 NaN
# 7                0.00    0.00         0.00  0.00                 NaN
# 9                0.00    0.00         0.00  0.00                 NaN
# 322            -47.87   -1.55        -3.09  0.00                 NaN
# 324              0.00    0.00         0.00  0.00                 NaN
# 327              0.00    0.00         0.00  0.00                 NaN
# 346              0.00    0.00         0.00  0.00                 NaN
# 32               0.00    0.00         0.00  0.00                 NaN
# 376              0.00    0.00         0.00  0.00                 NaN
# 26               0.00    0.00         0.00  0.00                 NaN
# 380              0.00    0.00         0.00  0.00                 NaN
# 110              0.00    0.00         0.00  0.00                 NaN
# 44               0.00    0.00         0.00  0.00                 NaN
# 372              0.00    0.00         0.00  0.00                 NaN
# 203              0.00    0.00         0.00  0.00                 NaN
# 298              0.00    0.00         0.00  0.00                 NaN
# 208              0.00    0.00         0.00  0.00                 NaN
# 309              0.00    0.00         0.00  0.00                 NaN
# 204              0.00    0.00         0.00  0.00                 NaN
# 363              0.00    0.00         0.00  0.00                 NaN
# 299              0.00    0.00         0.00  0.00                 NaN
# 308              0.00    0.00         0.00  0.00                 NaN
# 78               0.00    0.00         0.00  0.00                 NaN
# 295              0.00    0.00         0.00  0.00                 NaN
# 362              0.00    0.00         0.00  0.00                 NaN
# 51               0.00    0.00         0.00  0.00                 NaN
# 245             28.68   12.17         8.29  3.77                4.87
# 6               19.93    0.00        32.25  0.00               16.96
# 109             26.33   29.39        26.70  3.95                6.66
# 16              12.63   31.23        38.92  0.00               18.88
# 157              8.88    4.36        28.27  0.95                2.38
# 130             -5.13   -5.44         0.00  0.00              -14.54
# 239              8.88    4.36        28.27  0.95                2.38
# 127              0.00  -23.34        -0.46  0.00             -100.00
# 349            -11.77  -66.85        -2.44  0.00              -71.36
# 354              0.00  -39.69        -5.96  0.00             -100.00
# 343              0.00  -39.69        -5.96  0.00             -100.00
# 273              7.46    0.00        37.85  0.00               18.07
# 187              2.94   11.10        21.73  0.00               12.37
# 165              6.23   24.11        30.30  1.18                3.29
# 231             -1.39   -4.46       -49.08  0.00               -6.59
# 173              8.82   29.07        55.28  0.00                9.64
# 136             10.46   17.78        21.43  2.02                8.46
# 319           -149.18  -25.34       -12.12  0.00              -66.28
# 366              0.00  -41.77       -16.73  0.00                 NaN
# 325            -13.28  -68.93        -1.17  0.00              -15.70
# 321            -14.19  -41.94        -4.99  0.00              -17.56
# 55              16.52    5.75        11.77  1.53              -10.25
# 139              9.50   11.46        11.85  0.90                4.78
# 30              18.57   20.73        31.79  2.76                9.94
# 53               6.27    7.97         9.14  0.00                1.21
# 282             32.44    0.00        31.18  0.00                3.68
# 126              0.00  -22.66         0.07  0.00                 NaN
# ...
# 281                        1.00       0.00              1.00  33.30
# 125                        0.50       0.00              0.50  33.30
# 240                        1.00       0.00              0.90  33.30
# 230                        1.00       0.00              0.90  33.30
# 118                        0.82       0.00              0.50  33.20
# 75                         0.40       0.29              0.69  33.10
# 198                        0.54       0.00              0.00  32.80
# 293                        0.89       0.00              0.00  32.70
# 36                         0.40       0.00              0.13  32.70
# 18                         0.82       0.00              1.00  32.60
# 199                        0.72       0.00              0.50  32.60
# 179                        0.50       0.00              0.18  32.40
# 348                        0.50       1.00              0.50  32.20
# 58                         0.95       0.39              0.00  32.20
# 334                        0.50       1.00              0.50  32.20
# 48                         0.31       1.00              0.95  32.00
# 259                        1.00       1.00              0.77  31.90
# 105                        0.30       0.00              0.70  31.70
# 114                        0.50       0.00              0.50  31.60
# 313                        0.00       1.00              1.00  31.60
# 265                        1.00       0.02              0.29  31.60
# 88                         0.96       0.00              0.00  31.40
# 197                        0.54       0.00              0.00  31.40
# 142                        0.79       0.00              0.57  31.30
# 181                        0.09       0.00              0.89  31.30
# 339                        0.50       1.00              0.50  31.30
# 34                         0.97       0.00              1.00  31.20
# 155                        0.91       0.00              0.73  31.20
# 15                         1.00       0.00              0.81  31.00
# 275                        1.00       0.00              0.81  31.00
# 63                         0.37       0.00              0.22  31.00
# 37                         1.00       0.00              0.92  30.90
# 122                        0.00       0.00              0.50  30.90
# 377                        0.00       1.00              0.50  30.70
# 172                        0.00       0.00              0.16  30.50
# 301                        0.00       1.00              0.00  30.40
# 381                        0.00       1.00              0.00  30.40
# 302                        0.00       1.00              0.00  30.40
# 378                        1.00       0.25              0.97  30.00
# 190                        0.00       0.00              0.00  30.00
# 379                        0.00       0.00              0.00  29.90
# 144                        0.93       0.00              1.00  29.80
# 113                        0.50       0.00              0.50  29.70
# 1                          0.50       0.00              0.48  29.70
# 77                         0.86       1.00              0.93  29.50
# 107                        0.37       0.00              0.22  29.10
# 369                        0.50       1.00              0.50  29.10
# 294                        0.71       0.00              0.34  28.90
# 65                         0.76       0.00              0.00  28.80
# 174                        1.00       1.00              0.00  28.70
# 132                        0.92       0.00              0.00  28.70
# 229                        1.00       1.00              0.00  28.70
# 159                        0.55       0.00              1.00  28.70
# 205                        1.00       1.00              0.00  28.70
# 47                         1.00       0.64              1.00  28.20
# 39                         1.00       0.11              0.00  28.00
# 194                        0.40       0.00              0.61  28.00
# 168                        1.00       0.00              0.13  27.90
# 52                         0.00       0.57              0.00  27.80
# 163                        1.00       0.00              0.77  27.80
# 283                        0.93       0.00              1.00  27.80
# 22                         0.85       0.00              0.24  27.60
# 210                        0.85       0.00              0.24  27.60
# 98                         0.50       0.00              0.50  27.50
# 356                        0.50       0.00              0.50  27.50
# 352                        0.50       0.00              0.50  27.50
# 43                         0.50       0.00              0.50  27.50
# 330                        0.50       0.00              0.50  27.50
# 68                         0.50       0.00              0.50  27.50
# 7                          0.50       0.00              0.50  27.50
# 9                          0.50       0.00              0.50  27.50
# 322                        0.50       1.00              0.50  27.50
# 324                        0.50       0.00              0.50  27.50
# 327                        0.50       0.00              0.50  27.50
# 346                        0.50       0.00              0.50  27.50
# 32                         0.50       0.00              0.50  27.50
# 376                        0.50       0.00              0.50  27.50
# 26                         0.50       0.00              0.50  27.50
# 380                        0.50       0.00              0.50  27.50
# 110                        0.50       0.00              0.50  27.50
# 44                         0.50       0.00              0.50  27.50
# 372                        0.50       0.00              0.50  27.50
# 203                        0.50       0.00              0.50  27.50
# 298                        0.50       0.00              0.50  27.50
# 208                        0.50       0.00              0.50  27.50
# 309                        0.50       0.00              0.50  27.50
# 204                        0.50       0.00              0.50  27.50
# 363                        0.50       0.00              0.50  27.50
# 299                        0.50       0.00              0.50  27.50
# 308                        0.50       0.00              0.50  27.50
# 78                         0.50       0.00              0.50  27.50
# 295                        0.50       0.00              0.50  27.50
# 362                        0.50       0.00              0.50  27.50
# 51                         0.50       0.00              0.50  27.50
# 245                        0.87       0.66              0.90  27.20
# 6                          0.92       0.00              0.80  27.20
# 109                        0.40       0.29              0.69  27.10
# 16                         0.36       0.00              0.00  27.10
# 157                        0.85       0.00              0.57  27.00
# 130                        0.00       0.00              0.50  27.00
# 239                        0.85       0.00              0.57  27.00
# 127                        0.50       0.00              0.50  26.80
# 349                        0.50       1.00              0.50  26.80
# 354                        0.50       1.00              0.50  26.70
# 343                        0.50       1.00              0.50  26.70
# 273                        1.00       0.00              0.00  26.60
# 187                        0.31       0.00              0.00  26.60
# 165                        0.84       0.00              0.08  26.30
# 231                        0.72       0.03              0.00  26.30
# 173                        0.39       0.00              0.89  26.30
# 136                        1.00       0.00              0.91  26.30
# 319                        0.00       1.00              0.50  26.20
# 366                        0.50       0.00              0.50  26.10
# 325                        0.50       1.00              0.50  26.10
# 321                        0.50       1.00              0.00  26.10
# 55                         0.34       0.24              0.61  26.00
# 139                        0.47       0.00              0.51  26.00
# 30                         0.94       0.00              0.89  26.00
# 53                         0.83       0.38              0.00  25.60
# 282                        1.00       0.00              1.00  25.60
# 126                        0.50       0.00              0.50  25.50
# 266                        1.00       0.01              0.48  25.40
# 3                          0.89       0.00              0.98  25.30
# 24                         0.97       0.00              0.78  25.20
# 212                        0.97       0.00              0.78  25.10
# 318                        0.50       1.00              0.50  24.70
# 29                         0.93       0.00              0.65  24.60
# 12                         0.74       0.00              0.00  24.30
# 69                         0.56       0.20              0.77  24.20
# 178                        0.99       0.00              0.00  24.10
# 226                        0.00       1.00              0.50  23.80
# 382                        1.00       0.08              0.76  23.60
# 288                        0.40       1.00              0.48  23.40
# 134                        0.72       0.00              0.16  23.40
# 180                        1.00       0.11              0.43  23.30
# 360                        1.00       0.09              0.88  23.10
# 162                        1.00       0.00              0.77  23.00
# 141                        1.00       0.00              0.58  23.00
# 64                         0.03       0.00              0.00  23.00
# 106                        1.00       0.00              0.78  22.90
# 154                        1.00       0.00              1.00  22.80
# 100                        0.83       0.38              0.00  22.80
# 31                         1.00       0.00              0.78  22.80
# 201                        0.80       0.00              0.00  22.60
# 220                        1.00       0.06              1.00  22.50
# 120                        0.00       0.00              0.50  22.50
# 228                        1.00       0.06              1.00  22.50
# 146                        1.00       0.06              1.00  22.50
# 272                        0.99       0.00              0.00  22.00
# 40                         0.85       0.00              0.40  21.60
# 188                        0.00       0.00              0.53  21.60
# 140                        0.73       0.00              0.54  21.50
# 170                        1.00       0.06              0.83  21.40
# 224                        1.00       0.06              0.83  21.40
# 27                         0.99       0.00              1.00  21.20
# 175                        1.00       0.47              0.46  21.10
# 196                        0.35       0.00              0.00  21.10
# 56                         0.49       0.59              0.00  21.00
# 233                        0.88       0.00              0.00  20.90
# 150                        0.88       0.00              0.00  20.90
# 50                         0.01       0.81              0.00  20.50
# 166                        0.52       0.00              0.89  20.40
# 99                         0.40       0.00              0.00  20.10
# 25                         0.70       0.00              0.43  20.00
# 213                        0.70       0.00              0.43  20.00
# 215                        0.93       0.00              0.00  19.90
# 138                        0.00       0.00              0.66  19.80
# 49                         0.90       0.29              0.00  19.50
# 357                        0.95       0.00              0.26  19.30
# 70                         0.60       0.42              0.79  19.20
# 264                        1.00       1.00              0.60  19.00
# 102                        1.00       0.00              0.00  18.90
# 104                        0.86       0.00              0.59  18.70
# 280                        0.95       0.00              0.00  18.70
# 186                        0.33       0.00              0.89  18.60
# 54                         0.96       0.53              0.00  18.40
# 10                         0.00       0.00              1.00  18.40
# 0                          0.00       0.00              1.00  18.40
# 304                        1.00       0.69              0.73  18.40
# 209                        0.30       0.00              0.90  18.20
# 21                         0.30       0.00              0.90  18.20
# 108                        0.03       0.00              0.00  18.00
# 41                         1.00       0.00              0.00  17.70
# 133                        0.23       0.00              0.66  17.60
# 195                        0.40       0.00              0.84  17.50
# 128                        0.22       0.00              0.31  17.40
# 148                        0.96       0.75              1.00  17.40
# 177                        0.11       0.00              0.33  17.30
# 164                        0.77       0.00              1.00  17.20
# 192                        0.49       0.00              0.50  17.20
# 62                         0.58       0.00              0.00  16.90
# 135                        0.98       0.00              0.22  16.80
# 206                        0.00       0.00              0.00  16.30
# 296                        0.77       0.53              0.18  16.10
# 359                        0.89       0.00              0.93  16.10
# 112                        0.62       0.00              0.00  16.00
# 234                        0.28       0.00              0.00  15.70
# 151                        0.28       0.00              0.00  15.70
# 365                        0.95       0.30              0.52  15.50
# 262                        0.88       0.48              0.50  15.40
# 182                        0.98       0.00              0.84  15.10
# 355                        0.54       0.00              0.00  15.00
# 61                         0.86       0.00              0.00  15.00
# 274                        0.87       0.00              0.00  14.80
# 222                        0.95       0.00              1.00  14.60
# 235                        0.95       0.00              1.00  14.60
# 137                        0.95       0.00              1.00  14.60
# 60                         0.06       1.00              0.00  14.30
# 223                        0.42       0.00              0.04  14.30
# 227                        0.42       0.00              0.04  14.30
# 171                        0.42       0.00              0.04  14.30
# 176                        0.90       0.00              0.07  14.10
# 158                        0.71       0.00              0.97  14.10
# 143                        0.93       0.00              0.66  13.70
# 221                        0.93       0.00              0.66  13.70
# 161                        0.00       0.00              0.54  13.20
# 23                         0.39       0.00              0.00  13.10
# 193                        0.00       0.00              0.50  13.10
# 211                        0.39       0.00              0.00  13.10
# 28                         0.40       0.00              0.00  12.90
# 117                        0.00       0.00              0.50  12.50
# 147                        0.56       0.19              0.87  12.30
# 35                         0.73       0.00              0.96  11.80
# 129                        0.00       0.00              0.00  11.20
# 14                         0.26       0.00              0.00  10.00
# 361                        0.93       0.03              0.31   8.30
# 202                        0.40       0.00              0.00   7.60
# 184                        0.54       0.00              0.99   6.10

# %%
# ticker_df.to_csv('./analysis_result_yfinance/AI_supply_chain_stocks_v1.csv', index=False)
# ticker_df.to_csv('./analysis_result_yfinance/defence_stocks_v1.csv', index=False)
