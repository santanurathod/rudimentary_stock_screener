# %%
import os
import pandas as pd
import numpy as np
import PyPDF2

# %%
def read_pdf(file_path):
    """
    Read a PDF file and print its contents.
    
    Args:
        file_path (str): Path to the PDF file
    """
    try:
        # Open the PDF file in binary read mode
        with open(file_path, 'rb') as file:
            # Create a PDF reader object
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Get the number of pages
            num_pages = len(pdf_reader.pages)
            print(f"Number of pages: {num_pages}")
            
            # Read each page
            for page_num in range(num_pages):
                # Get the page object
                page = pdf_reader.pages[page_num]
                
                # Extract text from the page
                text = page.extract_text()
                print(f"\nPage {page_num + 1}:")
                print(text)
                
    except FileNotFoundError:
        print(f"Error: The file {file_path} was not found.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# %%
read_pdf('payment_history.PDF')
# Out:
# Number of pages: 7
#
# Page 1:
# 30.Mai2025
# Kontoauszug vom01.05.2025 bis30.05.2025
# Kontoinhaber: Santanu Subhash Rathod
# AlterSaldoper30.04.2025 IBAN von Seite Auszug
# +6.919,90 EUR DE77590700700039189600 7 1 5
# Haben Soll Vorgang Valuta Buchung
# -29,00 SEPALastschrifteinzug von
# FitXDeutschland GmbH02.05.
# 202502.05.
# 2025
# Verwendungszweck/ Kundenreferenz
# 87--0049-0005341 87-2045132 FitXAktionsvertrag 29.00
# EUR01.05.25-31.05.25
# 87--0049-0005341 /87-2045132
# Gläubiger-ID DE48ZZZ00000858428
# Mand-ID MLREF8704209
# RCURWiederholungslastschrift
# -5,78 Kartenzahlung
# Verwendungszweck/ Kundenreferenz02.05.
# 202502.05.
# 2025
# SANOOK-P ARKWAYPARADE//SINGAPORE/SG
# 29-04-2025T13:51:09 Kartennr .5354999999999962
# Original8,45SGD1EUR/1,47727 SGDEntgelt0,06
# EUR
# -1,20 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# Whippet//Swavesey/GB 30-04-2025T00:00:00 Kartennr.
# 5354999999999962 Original1,00GBP1EUR/0,84033
# GBPEntgelt0,01EUR
# -1,43 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB30-04-2025
# T13:11:50Kartennr .5354999999999962 Original1,20
# GBP1EUR/0,84507 GBPEntgelt0,01EUR
# -1,80 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# ZoyanLimited//Cambridge/GB 01-05-2025T13:31:21
# Kartennr .5354999999999962 Original1,50GBP1
# EUR/0,84269 GBPEntgelt0,02EUR
# Deutsche BankAG
# Filiale
# Saarbrücken
# Herrn
# Santanu Subhash RathodKaiserstraße 29-31
# 66111Saarbrücken
# Beratungsteam
# Sternplatz 2
# 66280SulzbachTelefon(0681)3002-229
# 24h-Kundenservice (069)910-100000000000003 /06500900 /20250531
#
# Page 2:
# Haben Soll Vorgang Valuta Buchung
# -3,60 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB01-05-2025
# T16:39:55 Kartennr .5354999999999962 Original3,00
# GBP1EUR/0,84269 GBPEntgelt0,04EUR
# -5,02 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# CHUROS COFFEE//WEST MOLESEY/GB 30-04-2025
# T08:03:00 Kartennr .5354999999999962 Original4,20
# GBP1EUR/0,84507 GBPEntgelt0,05EUR
# -5,81 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB30-04-2025
# T12:58:54 Kartennr .5354999999999962 Original4,85
# GBP1EUR/0,84347 GBPEntgelt0,06EUR
# -6,36 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# UNIVERSITY OFCAMBRIDG//CAMBRIDGE/GB
# 01-05-2025T00:00:00 Kartennr .5354999999999962
# Original5,32GBP1EUR/0,84444 GBPEntgelt0,06
# EUR
# -7,93 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# BUS.MR T626772191//SINGAPORE/SG 23-04-2025
# T16:04:39 Kartennr .5354999999999962 Original11,54
# SGD1EUR/1,47006 SGDEntgelt0,08EUR
# -19,02 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# HEATHROW RAILLINK//TERMINAL 4AT/GB
# 30-04-2025T06:38:55 Kartennr .5354999999999962
# Original15,90GBP1EUR/0,84439 GBPEntgelt0,19
# EUR
# -35,17 Kartenzahlung
# Verwendungszweck/ Kundenreferenz05.05.
# 202505.05.
# 2025
# GREATERANGLIA T.O//LONDON EC2M/GB
# 30-04-2025T00:00:00 Kartennr .5354999999999962
# Original29,40GBP1EUR/0,84434 GBPEntgelt0,35
# EUR
# -5,81 Kartenzahlung
# Verwendungszweck/ Kundenreferenz06.05.
# 202506.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB02-05-2025
# T12:06:55 Kartennr .5354999999999962 Original4,85
# GBP1EUR/0,84347 GBPEntgelt0,06EUR
# -6,64 Kartenzahlung
# Verwendungszweck/ Kundenreferenz06.05.
# 202506.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB03-05-2025
# T11:59:48Kartennr .5354999999999962 Original5,55
# GBP1EUR/0,84474 GBPEntgelt0,07EUR
# IBAN von Seite Auszug
# DE77590700700039189600 7 2 50000000003 /06500900 /20250531
#
# Page 3:
# Haben Soll Vorgang Valuta Buchung
# -8,97 Kartenzahlung
# Verwendungszweck/ Kundenreferenz06.05.
# 202506.05.
# 2025
# TESCOSTORES//CAMBRIDGESHIR/GB 03-05-2025
# T08:34:17 Kartennr .5354999999999962 Original7,50
# GBP1EUR/0,84459 GBPEntgelt0,09EUR
# -42,62 Kartenzahlung
# Verwendungszweck/ Kundenreferenz06.05.
# 202506.05.
# 2025
# SAINSBUR Y.SS.MKT//SIDNEY STREET/GB
# 03-05-2025T09:15:46 Kartennr .5354999999999962
# Original35,64GBP1EUR/0,84454 GBPEntgelt0,42
# EUR
# -65,52 Bargeldauszahlung GAA
# Verwendungszweck/ Kundenreferenz06.05.
# 202506.05.
# 2025
# HALXCAMBRIDGE//Cambridge/GB 03-05-2025
# T09:28:15 Kartennr .5354999999999962 Entgelt3,95
# EUR
# -3,12 Kartenzahlung
# Verwendungszweck/ Kundenreferenz07.05.
# 202507.05.
# 2025
# BUS.MR T629580587//SINGAPORE/SG 28-04-2025
# T17:52:28 Kartennr .5354999999999962 Original4,46
# SGD1EUR/1,44336 SGDEntgelt0,03EUR
# -5,09 Kartenzahlung
# Verwendungszweck/ Kundenreferenz07.05.
# 202507.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB05-05-2025
# T18:30:1 1Kartennr .5354999999999962 Original4,25
# GBP1EUR/0,84325 GBPEntgelt0,05EUR
# -4,61 Kartenzahlung
# Verwendungszweck/ Kundenreferenz08.05.
# 202508.05.
# 2025
# CAFFENEROCAMBRIDGE K//CAMBRIDGE/GB
# 05-05-2025T10:28:38 Kartennr .5354999999999962
# Original3,85GBP1EUR/0,84429 GBPEntgelt0,05
# EUR
# -5,73 Kartenzahlung
# Verwendungszweck/ Kundenreferenz08.05.
# 202508.05.
# 2025
# UNIVERSITY OFCAMBRIDG//CAMBRIDGE/GB
# 06-05-2025T00:00:00 Kartennr .5354999999999962
# Original4,80GBP1EUR/0,84656 GBPEntgelt0,06
# EUR
# -10,08 Kartenzahlung
# Verwendungszweck/ Kundenreferenz08.05.
# 202508.05.
# 2025
# OVERLEAF SHARELA TEX//LONDON/GB 07-05-2025
# T00:42:49 Kartennr .5354999999999962 Original8,40
# GBP1EUR/0,84168 GBPEntgelt0,10EUR
# IBAN von Seite Auszug
# DE77590700700039189600 7 3 50000000003 /06500900 /20250531
#
# Page 4:
# Haben Soll Vorgang Valuta Buchung
# -0,60 Kartenzahlung
# Verwendungszweck/ Kundenreferenz09.05.
# 202509.05.
# 2025
# CAFFIEND OFCAMBRIDGE//CAMBRIDGE/GB
# 07-05-2025T12:12:00 Kartennr .5354999999999962
# Original0,50GBP1EUR/0,84745 GBPEntgelt0,01
# EUR
# -0,60 Kartenzahlung
# Verwendungszweck/ Kundenreferenz09.05.
# 202509.05.
# 2025
# CAFFIEND OFCAMBRIDGE//CAMBRIDGE/GB
# 07-05-2025T12:08:00 Kartennr .5354999999999962
# Original0,50GBP1EUR/0,84745 GBPEntgelt0,01
# EUR
# -5,82 Kartenzahlung
# Verwendungszweck/ Kundenreferenz09.05.
# 202509.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB07-05-2025
# T18:28:35 Kartennr .5354999999999962 Original4,85
# GBP1EUR/0,84201 GBPEntgelt0,06EUR
# -6,52 Kartenzahlung
# Verwendungszweck/ Kundenreferenz09.05.
# 202509.05.
# 2025
# UNIVERSITY OFCAMBRIDG//CAMBRIDGE/GB
# 07-05-2025T00:00:00 Kartennr .5354999999999962
# Original5,44GBP1EUR/0,84210 GBPEntgelt0,06
# EUR
# -519,72 Kartenzahlung
# Verwendungszweck/ Kundenreferenz09.05.
# 202509.05.
# 2025
# BRITISH A1252209258925//LONDON/GB 07-05-2025
# T16:43:00 Kartennr.5354999999999962 Original435,82
# GBP1EUR/0,84695 GBPEntgelt5,15EUR
# -5,73 Kartenzahlung
# Verwendungszweck/ Kundenreferenz12.05.
# 202512.05.
# 2025
# ZoyanLimited//Cambridge/GB 08-05-2025T13:49:20
# Kartennr .5354999999999962 Original4,78GBP1
# EUR/0,84303 GBPEntgelt0,06EUR
# -13,41 Kartenzahlung
# Verwendungszweck/ Kundenreferenz12.05.
# 202512.05.
# 2025
# SAINSBUR YSS.MKTS//CAMBRIDGE 728/GB
# 08-05-2025T17:26:21 Kartennr .5354999999999962
# Original11,20GBP1EUR/0,84337 GBPEntgelt0,13
# EUR
# -2,16 Kartenzahlung
# Verwendungszweck/ Kundenreferenz13.05.
# 202513.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB09-05-2025
# T12:30:54 Kartennr .5354999999999962 Original1,80
# GBP1EUR/0,841 12GBPEntgelt0,02EUR
# IBAN von Seite Auszug
# DE77590700700039189600 7 4 50000000003 /06500900 /20250531
#
# Page 5:
# Haben Soll Vorgang Valuta Buchung
# -3,00 Kartenzahlung
# Verwendungszweck/ Kundenreferenz13.05.
# 202513.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB09-05-2025
# T15:05:34 Kartennr .5354999999999962 Original2,50
# GBP1EUR/0,84175 GBPEntgelt0,03EUR
# -5,82 Kartenzahlung
# Verwendungszweck/ Kundenreferenz13.05.
# 202513.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB09-05-2025
# T12:06:05 Kartennr .5354999999999962 Original4,85
# GBP1EUR/0,84201 GBPEntgelt0,06EUR
# -8,22 Kartenzahlung
# Verwendungszweck/ Kundenreferenz13.05.
# 202513.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB11-05-2025
# T11:30:02Kartennr .5354999999999962 Original6,85
# GBP1EUR/0,84152 GBPEntgelt0,08EUR
# -8,22 Kartenzahlung
# Verwendungszweck/ Kundenreferenz13.05.
# 202513.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB10-05-2025
# T13:38:54 Kartennr .5354999999999962 Original6,85
# GBP1EUR/0,84152 GBPEntgelt0,08EUR
# -13,93 Kartenzahlung
# Verwendungszweck/ Kundenreferenz13.05.
# 202513.05.
# 2025
# SHELLNEWNHAM//CAMBRIDGE/GB 11-05-2025
# T16:09:07 Kartennr .5354999999999962 Original11,60
# GBP1EUR/0,841 18GBPEntgelt0,14EUR
# -528,71 Kartenzahlung
# Verwendungszweck/ Kundenreferenz14.05.
# 202514.05.
# 2025
# Interglobe AviationLT//NEW DELHI/IN 12-05-2025
# T00:00:00 Kartennr .5354999999999962 Entgelt5,23
# EUR
# -2,89 Kartenzahlung
# Verwendungszweck/ Kundenreferenz15.05.
# 202515.05.
# 2025
# SHELLNEWNHAM//CAMBRIDGE/GB 13-05-2025
# T09:21:14 Kartennr .5354999999999962 Original2,40
# GBP1EUR/0,83916 GBPEntgelt0,03EUR
# -2,17 Kartenzahlung
# Verwendungszweck/ Kundenreferenz19.05.
# 202519.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB15-05-2025
# T12:33:01 Kartennr .5354999999999962 Original1,80
# GBP1EUR/0,83720 GBPEntgelt0,02EUR
# -3,02 Kartenzahlung
# Verwendungszweck/ Kundenreferenz19.05.
# 202519.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB15-05-2025
# T16:44:02 Kartennr .5354999999999962 Original2,50
# GBP1EUR/0,83612 GBPEntgelt0,03EUR
# IBAN von Seite Auszug
# DE77590700700039189600 7 5 50000000003 /06500900 /20250531
#
# Page 6:
# Haben Soll Vorgang Valuta Buchung
# -4,65 Kartenzahlung
# Verwendungszweck/ Kundenreferenz19.05.
# 202519.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB15-05-2025
# T12:18:45 Kartennr .5354999999999962 Original3,85
# GBP1EUR/0,83695 GBPEntgelt0,05EUR
# -5,99 SEPALastschrifteinzug von
# PayPalEuropeS.a.r.l.etCieS.C.A20.05.
# 202520.05.
# 2025
# Verwendungszweck/ Kundenreferenz
# 1042279602668/PP .4008.PP/. SpotifyAB,IhrEinkauf
# beiSpotifyAB
# 1042279602668
# Gläubiger-ID LU96ZZZ0000000000000000058
# Mand-ID 53WJ2257NZ38A
# RCURWiederholungslastschrift
# -5,86 Kartenzahlung
# Verwendungszweck/ Kundenreferenz20.05.
# 202520.05.
# 2025
# DARWINCOLLEGE//CAMBRIDGE 012/GB16-05-2025
# T12:16:09 Kartennr .5354999999999962 Original4,85
# GBP1EUR/0,83620 GBPEntgelt0,06EUR
# -10,02 Kartenzahlung
# Verwendungszweck/ Kundenreferenz20.05.
# 202520.05.
# 2025
# SHELLEY ANDSARAHS//CAMBRIDGE/GB 16-05-2025
# T08:43:24 Kartennr .5354999999999962 Original8,30
# GBP1EUR/0,83669 GBPEntgelt0,10EUR
# -10,62 Kartenzahlung
# Verwendungszweck/ Kundenreferenz20.05.
# 202520.05.
# 2025
# PRETAMANGER//London/GB 17-05-2025T06:53:50
# Kartennr .5354999999999962 Original8,79GBP1
# EUR/0,83634 GBPEntgelt0,11EUR
# -21,85 Kartenzahlung
# Verwendungszweck/ Kundenreferenz20.05.
# 202520.05.
# 2025
# GREATERANGLIA//LONDON/GB 16-05-2025T12:57:00
# Kartennr .5354999999999962 Original18,10GBP1
# EUR/0,83680 GBPEntgelt0,22EUR
# -83,86 Kartenzahlung
# Verwendungszweck/ Kundenreferenz20.05.
# 202520.05.
# 2025
# AIRBNB .HMWHEAZTDX//303-080-8380/LU 16-05-2025
# T00:00:00 Kartennr .5354999999999962 Original69,49
# GBP1EUR/0,83692 GBPEntgelt0,83EUR
# -768,82 Kartenzahlung
# Verwendungszweck/ Kundenreferenz21.05.
# 202521.05.
# 2025
# Interglobe AviationLT//NEW DELHI/IN 19-05-2025
# T00:00:00 Kartennr .5354999999999962 Entgelt7,61
# EUR
# IBAN von Seite Auszug
# DE77590700700039189600 7 6 50000000003 /06500900 /20250531
#
# Page 7:
# Haben Soll Vorgang Valuta Buchung
# -33,74 Kartenzahlung
# Verwendungszweck/ Kundenreferenz23.05.
# 202523.05.
# 2025
# HOTELCOUNTR YVILLAP//KATHMANDU/NP
# 20-05-2025T14:22:04 Kartennr .5354999999999962
# Original5067,00 NPR1EUR/151,661 17NPREntgelt
# 0,33EUR
# -5,11 Kartenzahlung
# Verwendungszweck/ Kundenreferenz27.05.
# 202527.05.
# 2025
# TRADITIONAL HOMES PVT//KA THMANDU/NP
# 24-05-2025T10:13:00 Kartennr .5354999999999962
# Original770,00NPR1EUR/152,17391 NPREntgelt
# 0,05EUR
# -39,67 Bargeldauszahlung GAA
# Verwendungszweck/ Kundenreferenz27.05.
# 202527.05.
# 2025
# 1007053//Lal/NP 23-05-2025T19:20:51 Kartennr .
# 5354999999999962 Original5500,00 NPR1
# EUR/153,97536 NPREntgelt3,95EUR
# +2.928,49 SEPAÜberweisung von
# CISPA-Helmholtz-Zentrum furInformationssicherheit
# gGmbH29.05.
# 202529.05.
# 2025
# Verwendungszweck/ Kundenreferenz
# Verdienstabrechnung 05.25/1
# 2025052122494421000000048000002298
# ABWACISPAgGmbH
# SALALohn/Gehalt
# NeuerSaldo
# +7.447,35 EURKontonummer
# 0391896 00Filialnummer
# 740
# BIC(SWIFT)
# DEUTDEDB595
# WichtigeHinweise
# Bitteerheben SieEinwendungen gegeneinzelne Buchungen unverzüglich. Schecks, Wechselundsonstige Lastschriften schreiben wirunterdemVorbehalt
# desEingangs gut.Derangegebene Kontostand berücksichtigt nichtdieWertstellung derBuchungen (sieheobenunter"Valuta").
# SomitkönnenbeiVerfügungen1)möglicherweise ZinsenfürdieInanspruchnahme einereingeräumten odergeduldeten Kontoüberziehung anfallen.
# Dieabgerechneten Leistungen sindalsBank-oderFinanzdienstleistungen vonderUmsatzsteuer befreit,sofernUmsatzsteuer nichtgesondert
# ausgewiesen ist.Umsatzsteuer IDNr.:Deutsche BankAG,60262Frankfurt DE114103379
# Guthaben sindalsEinlagen nachMaßgabe desEinlagensicherungsgesetzes entschädigungsfähig. NähereInformationen könnendem"Informationsbogen
# fürdenEinleger" entnommen werden.
# 1)DerBegriffumfasst unteranderem dierelevanten Zahlungskontendienste "Bargeldauszahlung" und"Überweisung".
# IBAN von Seite Auszug
# DE77590700700039189600 7 7 50000000003 /06500900 /20250531
